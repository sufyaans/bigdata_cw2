# %%
import pandas as pd
# df = pd.read_csv('https://raw.githubusercontent.com/TheifX/datacw/main/diabetic_data.csv?token=GHSAT0AAAAAABSGKJ2ROZNBPN64PAA5ZAB2YRMRSLQ')
df = pd.read_csv('diabetic_data.csv')


df.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-64337af3fff3> in <module>
#       1 import pandas as pd
#       2 # df = pd.read_csv('https://raw.githubusercontent.com/TheifX/datacw/main/diabetic_data.csv?token=GHSAT0AAAAAABSGKJ2ROZNBPN64PAA5ZAB2YRMRSLQ')
# ----> 3 df = pd.read_csv('diabetic_data.csv')
#       4
#       5
#
# /usr/lib/python3/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# /usr/lib/python3/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# /usr/lib/python3/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /usr/lib/python3/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# /usr/lib/python3/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'diabetic_data.csv' does not exist: b'diabetic_data.csv'

# %% [markdown]
# # <font color=red>Start of 1.1 Data cleaning and transformation</font>

# %% [markdown]
# ## a. Show the shape of the dataframe. Replace all missing values with the numpy.nan.

# %%
import numpy as np

df = df.replace('?', np.nan) # replace ? with nan
# # data = df.replace('^\s+', np.nan, regex=True) # replace empty spaces with nan
pd.isnull(df).sum()
# Out:
# encounter_id                    0
# patient_nbr                     0
# race                         2273
# gender                          0
# age                             0
# weight                      98569
# admission_type_id               0
# discharge_disposition_id        0
# admission_source_id             0
# time_in_hospital                0
# payer_code                  40256
# medical_specialty           49949
# num_lab_procedures              0
# num_procedures                  0
# num_medications                 0
# number_outpatient               0
# number_emergency                0
# number_inpatient                0
# diag_1                         21
# diag_2                        358
# diag_3                       1423
# number_diagnoses                0
# max_glu_serum                   0
# A1Cresult                       0
# metformin                       0
# repaglinide                     0
# nateglinide                     0
# chlorpropamide                  0
# glimepiride                     0
# acetohexamide                   0
# glipizide                       0
# glyburide                       0
# tolbutamide                     0
# pioglitazone                    0
# rosiglitazone                   0
# acarbose                        0
# miglitol                        0
# troglitazone                    0
# tolazamide                      0
# examide                         0
# citoglipton                     0
# insulin                         0
# glyburide-metformin             0
# glipizide-metformin             0
# glimepiride-pioglitazone        0
# metformin-rosiglitazone         0
# metformin-pioglitazone          0
# change                          0
# diabetesMed                     0
# readmitted                      0
# dtype: int64

# %% [markdown]
# ## b. Drop all columns that have more than 50% of missing values. You can also drop columns for which over 95% of their values are the same.

# %%
percentage = int(((100-50)/100)*df.shape[0] + 1)
df = df.dropna(thresh=percentage, axis=1)
Percentage_missing = df.isnull().sum() * 100 / len(df)
missing_value = pd.DataFrame({'percent_missing': Percentage_missing})
print(missing_value)
# Out:
#                           percent_missing
# encounter_id                     0.000000
# patient_nbr                      0.000000
# race                             2.233555
# gender                           0.000000
# age                              0.000000
# admission_type_id                0.000000
# discharge_disposition_id         0.000000
# admission_source_id              0.000000
# time_in_hospital                 0.000000
# payer_code                      39.557416
# medical_specialty               49.082208
# num_lab_procedures               0.000000
# num_procedures                   0.000000
# num_medications                  0.000000
# number_outpatient                0.000000
# number_emergency                 0.000000
# number_inpatient                 0.000000
# diag_1                           0.020636
# diag_2                           0.351787
# diag_3                           1.398306
# number_diagnoses                 0.000000
# max_glu_serum                    0.000000
# A1Cresult                        0.000000
# metformin                        0.000000
# repaglinide                      0.000000
# nateglinide                      0.000000
# chlorpropamide                   0.000000
# glimepiride                      0.000000
# acetohexamide                    0.000000
# glipizide                        0.000000
# glyburide                        0.000000
# tolbutamide                      0.000000
# pioglitazone                     0.000000
# rosiglitazone                    0.000000
# acarbose                         0.000000
# miglitol                         0.000000
# troglitazone                     0.000000
# tolazamide                       0.000000
# examide                          0.000000
# citoglipton                      0.000000
# insulin                          0.000000
# glyburide-metformin              0.000000
# glipizide-metformin              0.000000
# glimepiride-pioglitazone         0.000000
# metformin-rosiglitazone          0.000000
# metformin-pioglitazone           0.000000
# change                           0.000000
# diabetesMed                      0.000000
# readmitted                       0.000000

# %%
a = (df['race'].value_counts()/df['race'].count())*100
same = pd.DataFrame({'same_percentage': a})
print(same)
column = same["same_percentage"]
max_value = column.max()
if  max_value> 95.00:
    print ("more than 95 %")
else:
    print(" percentage" + str(max_value))
# Out:
#                  same_percentage
# Caucasian              76.486788
# AfricanAmerican        19.307891
# Hispanic                2.047380
# Other                   1.513674
# Asian                   0.644266
#  percentage76.48678801523725

# %%
for (columnName,i) in df.iteritems():
    a = (df[columnName].value_counts()/df[columnName].count())*100
    same = pd.DataFrame({'same_percentage': a})
    column = same["same_percentage"]
    max_value = column.max()
    if  max_value> 95.00:
       print (columnName+" more than 95 %, dropped")
       df.drop(columnName, inplace=True, axis = 1)

    else:
       print(columnName+" passed")
# Out:
# encounter_id passed
# patient_nbr passed
# race passed
# gender passed
# age passed
# admission_type_id passed
# discharge_disposition_id passed
# admission_source_id passed
# time_in_hospital passed
# payer_code passed
# medical_specialty passed
# num_lab_procedures passed
# num_procedures passed
# num_medications passed
# number_outpatient passed
# number_emergency passed
# number_inpatient passed
# diag_1 passed
# diag_2 passed
# diag_3 passed
# number_diagnoses passed
# max_glu_serum passed
# A1Cresult passed
# metformin passed
# repaglinide more than 95 %, dropped
# nateglinide more than 95 %, dropped
# chlorpropamide more than 95 %, dropped
# glimepiride passed
# acetohexamide more than 95 %, dropped
# glipizide passed
# glyburide passed
# tolbutamide more than 95 %, dropped
# pioglitazone passed
# rosiglitazone passed
# acarbose more than 95 %, dropped
# miglitol more than 95 %, dropped
# troglitazone more than 95 %, dropped
# tolazamide more than 95 %, dropped
# examide more than 95 %, dropped
# citoglipton more than 95 %, dropped
# insulin passed
# glyburide-metformin more than 95 %, dropped
# glipizide-metformin more than 95 %, dropped
# glimepiride-pioglitazone more than 95 %, dropped
# metformin-rosiglitazone more than 95 %, dropped
# metformin-pioglitazone more than 95 %, dropped
# change passed
# diabetesMed passed
# readmitted passed

# %%
#df = df.loc[~df.discharge_disposition_id.isin([11,13,14,19,20,21])]
df.shape
# Out:
# (101766, 33)

# %% [markdown]
# ## c. Transform the age to be the middle value in each given range.

# %%
#range age to middle value
RangeAge = df.age.str.extract('(\d+)-(\d+)')
df.age = RangeAge.astype('int').mean(axis=1).astype('int').round(0)

df.loc[:, ['age']]
# Out:
#         age
# 0         5
# 1        15
# 2        25
# 3        35
# 4        45
# ...     ...
# 101761   75
# 101762   85
# 101763   75
# 101764   85
# 101765   75
#
# [101766 rows x 1 columns]

# %% [markdown]
# ## d. Replace possible missing values in the columns diag_1, diag_2, and diag_3 by the number 0.

# %%
#replace all NaN to 0 in diag_1/2/3
df['diag_1'] = df['diag_1'].fillna(0)
df['diag_2'] = df['diag_2'].fillna(0)
df['diag_3'] = df['diag_3'].fillna(0)

df.loc[:, ['diag_1','diag_2','diag_3']]
# Out:
#         diag_1  diag_2 diag_3
# 0       250.83       0      0
# 1          276  250.01    255
# 2          648     250    V27
# 3            8  250.43    403
# 4          197     157    250
# ...        ...     ...    ...
# 101761  250.13     291    458
# 101762     560     276    787
# 101763      38     590    296
# 101764     996     285    998
# 101765     530     530    787
#
# [101766 rows x 3 columns]

# %%
df.loc[:, :]
# Out:
#         encounter_id  patient_nbr             race  gender  age  \
# 0            2278392      8222157        Caucasian  Female    5
# 1             149190     55629189        Caucasian  Female   15
# 2              64410     86047875  AfricanAmerican  Female   25
# 3             500364     82442376        Caucasian    Male   35
# 4              16680     42519267        Caucasian    Male   45
# ...              ...          ...              ...     ...  ...
# 101761     443847548    100162476  AfricanAmerican    Male   75
# 101762     443847782     74694222  AfricanAmerican  Female   85
# 101763     443854148     41088789        Caucasian    Male   75
# 101764     443857166     31693671        Caucasian  Female   85
# 101765     443867222    175429310        Caucasian    Male   75
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                       6                        25                    1
# 1                       1                         1                    7
# 2                       1                         1                    7
# 3                       1                         1                    7
# 4                       1                         1                    7
# ...                   ...                       ...                  ...
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital payer_code  ... metformin  glimepiride  glipizide  \
# 0                      1        NaN  ...        No           No         No
# 1                      3        NaN  ...        No           No         No
# 2                      2        NaN  ...        No           No     Steady
# 3                      2        NaN  ...        No           No         No
# 4                      1        NaN  ...        No           No     Steady
# ...                  ...        ...  ...       ...          ...        ...
# 101761                 3         MC  ...    Steady           No         No
# 101762                 5         MC  ...        No           No         No
# 101763                 1         MC  ...    Steady           No         No
# 101764                10         MC  ...        No           No     Steady
# 101765                 6        NaN  ...        No           No         No
#
#         glyburide  pioglitazone  rosiglitazone  insulin change diabetesMed  \
# 0              No            No             No       No     No          No
# 1              No            No             No       Up     Ch         Yes
# 2              No            No             No       No     No         Yes
# 3              No            No             No       Up     Ch         Yes
# 4              No            No             No   Steady     Ch         Yes
# ...           ...           ...            ...      ...    ...         ...
# 101761         No            No             No     Down     Ch         Yes
# 101762         No            No             No   Steady     No         Yes
# 101763         No            No             No     Down     Ch         Yes
# 101764         No        Steady             No       Up     Ch         Yes
# 101765         No            No             No       No     No          No
#
#        readmitted
# 0              NO
# 1             >30
# 2              NO
# 3              NO
# 4              NO
# ...           ...
# 101761        >30
# 101762         NO
# 101763         NO
# 101764         NO
# 101765         NO
#
# [101766 rows x 33 columns]

# %% [markdown]
# ## e. Drop all rows with missing values

# %%
df = df.dropna()

df.loc[:, :]
# Out:
#         encounter_id  patient_nbr       race  gender  age  admission_type_id  \
# 20446       72091308     20123568  Caucasian  Female   75                  1
# 20737       72848634     20377854  Caucasian  Female   65                  2
# 20824       73062156     20408121  Caucasian  Female   95                  1
# 21083       73731852     20542797  Caucasian    Male   75                  1
# 23879       81355914      7239654  Caucasian  Female   75                  1
# ...              ...          ...        ...     ...  ...                ...
# 101735     443739044    106595208  Caucasian    Male   75                  2
# 101743     443793668     47293812  Caucasian    Male   85                  1
# 101747     443804570     33230016  Caucasian  Female   75                  1
# 101749     443816024    106392411  Caucasian  Female   75                  3
# 101764     443857166     31693671  Caucasian  Female   85                  2
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# 20446                         22                    7                 7
# 20737                          1                    1                 3
# 20824                          1                    7                 4
# 21083                          2                    7                10
# 23879                          3                    6                12
# ...                          ...                  ...               ...
# 101735                         6                    7                 6
# 101743                        13                    7                 3
# 101747                        22                    7                 8
# 101749                         6                    1                 3
# 101764                         3                    7                10
#
#        payer_code  ... metformin  glimepiride  glipizide  glyburide  \
# 20446          MC  ...        No           No         No         No
# 20737          MC  ...        No           No         No         No
# 20824          MC  ...        No       Steady         No         No
# 21083          MC  ...    Steady           No         No         No
# 23879          UN  ...        No           No         No         No
# ...           ...  ...       ...          ...        ...        ...
# 101735         MC  ...        No           No         No         No
# 101743         MC  ...        No           No         No         Up
# 101747         MC  ...        No           No         No         No
# 101749         MC  ...    Steady           No     Steady         No
# 101764         MC  ...        No           No     Steady         No
#
#         pioglitazone  rosiglitazone  insulin change diabetesMed readmitted
# 20446             Up             No   Steady     Ch         Yes         NO
# 20737             No             No   Steady     No         Yes         NO
# 20824             No             No       No     No         Yes         NO
# 21083             No             No   Steady     Ch         Yes         NO
# 23879             No             No   Steady     No         Yes         NO
# ...              ...            ...      ...    ...         ...        ...
# 101735            No             No       Up     Ch         Yes         NO
# 101743            No         Steady     Down     Ch         Yes         NO
# 101747            No             No   Steady     No         Yes        >30
# 101749            No             No   Steady     Ch         Yes         NO
# 101764        Steady             No       Up     Ch         Yes         NO
#
# [27140 rows x 33 columns]

# %%
df.shape
# Out:
# (27140, 33)

# %% [markdown]
# ## f. Identify all numerical features and form a list of numerical features and another for the remaining categorical features.

# %%
#List of numerical features and categorical features

numerics = ['int64']

numdf = df.select_dtypes(include = numerics)
catdf = df.select_dtypes(exclude = numerics)

numlist = list(numdf.columns.values.tolist())
catlist = list(catdf.columns.values.tolist())

print("Numerical feature:") 
print(numlist)
print("\nCategorical feature:") 
print(catlist)
# Out:
# Numerical feature:
# ['encounter_id', 'patient_nbr', 'age', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id', 'time_in_hospital', 'num_lab_procedures', 'num_procedures', 'num_medications', 'number_outpatient', 'number_emergency', 'number_inpatient', 'number_diagnoses']
#
# Categorical feature:
# ['race', 'gender', 'payer_code', 'medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'max_glu_serum', 'A1Cresult', 'metformin', 'glimepiride', 'glipizide', 'glyburide', 'pioglitazone', 'rosiglitazone', 'insulin', 'change', 'diabetesMed', 'readmitted']

# %%
numdf.loc[:, :]
# Out:
#         encounter_id  patient_nbr  age  admission_type_id  \
# 20446       72091308     20123568   75                  1
# 20737       72848634     20377854   65                  2
# 20824       73062156     20408121   95                  1
# 21083       73731852     20542797   75                  1
# 23879       81355914      7239654   75                  1
# ...              ...          ...  ...                ...
# 101735     443739044    106595208   75                  2
# 101743     443793668     47293812   85                  1
# 101747     443804570     33230016   75                  1
# 101749     443816024    106392411   75                  3
# 101764     443857166     31693671   85                  2
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# 20446                         22                    7                 7
# 20737                          1                    1                 3
# 20824                          1                    7                 4
# 21083                          2                    7                10
# 23879                          3                    6                12
# ...                          ...                  ...               ...
# 101735                         6                    7                 6
# 101743                        13                    7                 3
# 101747                        22                    7                 8
# 101749                         6                    1                 3
# 101764                         3                    7                10
#
#         num_lab_procedures  num_procedures  num_medications  \
# 20446                   58               2               15
# 20737                   59               3               11
# 20824                   56               1                9
# 21083                   68               1               18
# 23879                   77               5               19
# ...                    ...             ...              ...
# 101735                  46               5               14
# 101743                  45               0               26
# 101747                  51               6               19
# 101749                  27               1               29
# 101764                  45               2               21
#
#         number_outpatient  number_emergency  number_inpatient  \
# 20446                   0                 0                 0
# 20737                   0                 0                 0
# 20824                   0                 0                 0
# 21083                   0                 0                 0
# 23879                   0                 0                 0
# ...                   ...               ...               ...
# 101735                  0                 0                 1
# 101743                  1                 0                 1
# 101747                  0                 0                 0
# 101749                  0                 1                 0
# 101764                  0                 0                 1
#
#         number_diagnoses
# 20446                  9
# 20737                  6
# 20824                  6
# 21083                  6
# 23879                  5
# ...                  ...
# 101735                 9
# 101743                 9
# 101747                 9
# 101749                 9
# 101764                 9
#
# [27140 rows x 14 columns]

# %%
catdf.loc[:, :]
# Out:
#              race  gender payer_code           medical_specialty diag_1  \
# 20446   Caucasian  Female         MC  Orthopedics-Reconstructive    821
# 20737   Caucasian  Female         MC                  Nephrology    V56
# 20824   Caucasian  Female         MC            Emergency/Trauma    532
# 21083   Caucasian    Male         MC            InternalMedicine    682
# 23879   Caucasian  Female         UN            InternalMedicine    238
# ...           ...     ...        ...                         ...    ...
# 101735  Caucasian    Male         MC            Emergency/Trauma    575
# 101743  Caucasian    Male         MC            Emergency/Trauma    486
# 101747  Caucasian  Female         MC            InternalMedicine    410
# 101749  Caucasian  Female         MC                 Orthopedics    715
# 101764  Caucasian  Female         MC             Surgery-General    996
#
#         diag_2 diag_3 max_glu_serum A1Cresult metformin glimepiride glipizide  \
# 20446      276    285          None      None        No          No        No
# 20737      403    599          None      None        No          No        No
# 20824      428    535          None      None        No      Steady        No
# 21083      427    276          None      None    Steady          No        No
# 23879   250.02    733          None        >8        No          No        No
# ...        ...    ...           ...       ...       ...         ...       ...
# 101735     577    250          None      Norm        No          No        No
# 101743     276    428          None      None        No          No        No
# 101747     311    250          None        >7        No          No        No
# 101749     401    250          None      Norm    Steady          No    Steady
# 101764     285    998          None      None        No          No    Steady
#
#        glyburide pioglitazone rosiglitazone insulin change diabetesMed  \
# 20446         No           Up            No  Steady     Ch         Yes
# 20737         No           No            No  Steady     No         Yes
# 20824         No           No            No      No     No         Yes
# 21083         No           No            No  Steady     Ch         Yes
# 23879         No           No            No  Steady     No         Yes
# ...          ...          ...           ...     ...    ...         ...
# 101735        No           No            No      Up     Ch         Yes
# 101743        Up           No        Steady    Down     Ch         Yes
# 101747        No           No            No  Steady     No         Yes
# 101749        No           No            No  Steady     Ch         Yes
# 101764        No       Steady            No      Up     Ch         Yes
#
#        readmitted
# 20446          NO
# 20737          NO
# 20824          NO
# 21083          NO
# 23879          NO
# ...           ...
# 101735         NO
# 101743         NO
# 101747        >30
# 101749         NO
# 101764         NO
#
# [27140 rows x 19 columns]

# %% [markdown]
# ## g. Identify outliers in the numerical columns and remove them. To keep it simple, you may decide to only keep values that are within 3 standard deviations away from the mean for each feature of the dataset.

# %%
#Keep values that are within 3 standard deviations away
for features in numlist:
    ##mean = df[features].mean()
    mean = np.mean(df[features])
    std = np.std(df[features])
    df = df[(df[features] >= mean-(3*std)) & (df[features] <= mean+(3*std))]

df.shape
df.loc[:,:]
# Out:
#         encounter_id  patient_nbr       race  gender  age  admission_type_id  \
# 20737       72848634     20377854  Caucasian  Female   65                  2
# 20824       73062156     20408121  Caucasian  Female   95                  1
# 21083       73731852     20542797  Caucasian    Male   75                  1
# 23879       81355914      7239654  Caucasian  Female   75                  1
# 23922       81458964     15466212  Caucasian    Male   75                  1
# ...              ...          ...        ...     ...  ...                ...
# 101278     437309498     52653654  Caucasian    Male   65                  1
# 101281     437320502     97591293  Caucasian  Female   65                  3
# 101282     437320700     44404956  Caucasian    Male   85                  1
# 101284     437331638    142026269  Caucasian    Male   85                  2
# 101286     437331728     46488123  Caucasian  Female   85                  2
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# 20737                          1                    1                 3
# 20824                          1                    7                 4
# 21083                          2                    7                10
# 23879                          3                    6                12
# 23922                          3                    6                12
# ...                          ...                  ...               ...
# 101278                         1                    7                 7
# 101281                         1                    1                 3
# 101282                         6                    7                 3
# 101284                         1                    4                 3
# 101286                         1                    1                 2
#
#        payer_code  ... metformin  glimepiride  glipizide  glyburide  \
# 20737          MC  ...        No           No         No         No
# 20824          MC  ...        No       Steady         No         No
# 21083          MC  ...    Steady           No         No         No
# 23879          UN  ...        No           No         No         No
# 23922          MC  ...        No           No         No         No
# ...           ...  ...       ...          ...        ...        ...
# 101278         BC  ...    Steady           No         No         No
# 101281         PO  ...        No           No         No         No
# 101282         MC  ...        No           No         No         No
# 101284         MC  ...    Steady           No         No         No
# 101286         MC  ...        No           No         No         No
#
#         pioglitazone  rosiglitazone  insulin change diabetesMed readmitted
# 20737             No             No   Steady     No         Yes         NO
# 20824             No             No       No     No         Yes         NO
# 21083             No             No   Steady     Ch         Yes         NO
# 23879             No             No   Steady     No         Yes         NO
# 23922             No             No       No     No          No         NO
# ...              ...            ...      ...    ...         ...        ...
# 101278            No             No       No     No         Yes         NO
# 101281            No             No       No     No          No        >30
# 101282            No             No   Steady     No         Yes         NO
# 101284        Steady             No       Up     Ch         Yes         NO
# 101286            No             No       No     No          No         NO
#
# [23316 rows x 33 columns]

# %% [markdown]
# ## Remove duplicates in the column patient_nbr and show the shape of the resulting dataframe.

# %%
#Remove duplicates in the column patient_nbr
#df = df.drop_duplicates(subset=['patient_nbr'], keep='first')
df = df.drop_duplicates(subset=['patient_nbr'])

#check shape of resulting dataframe
df.shape

df.loc[:,'diag_1']
#print(icd[(icd['ICD_Code'] == '532')])
# Out:
# 20737     V56
# 20824     532
# 21083     682
# 23879     238
# 23922     532
#          ...
# 101249    191
# 101268    410
# 101278    552
# 101284    491
# 101286    414
# Name: diag_1, Length: 17507, dtype: object

# %% [markdown]
# # <font color=red>1.2 Data Exploration</font>

# %% [markdown]
# ## Join both datasets diabetic_data.csv and icd_codes.csv.

# %%
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

#Not sure but joined the datasets
# icd = pd.read_csv('https://raw.githubusercontent.com/TheifX/datacw/main/icd_codes.csv?token=GHSAT0AAAAAABSGKJ2RNYAUUPLWAB723AJ6YRMRTPQ')
icd = pd.read_csv('icd_codes.csv')

icd.shape


description = []

for index, row in df.iterrows():
  diag = df.diag_1[index]
  descRow = icd[(icd['ICD_Code'] == diag)]
  try:
    desc = descRow['Description'].values[0]
    description.append(desc)
  except:
    description.append("None")

print(description)
df['Description'] = description
df.loc[:,:]
# Out:
# ['Aftercare involving intermittent dialysis', 'Duodenal ulcer', 'Other cellulitis and abscess', 'Neoplasm of uncertain behaviour of other and unspecified sites and tissues', 'Duodenal ulcer', 'Diabetes with other specified manifestations, type II or unspecified type, not stated as uncontrolled', 'Candidiasis', 'Complications peculiar to certain specified procedures', 'Cholelithiasis', 'Diseases of pancreas', 'Heart failure', 'Disorders of muscle, ligament and fascia', 'Other conditions of brain', 'Intervertebral disk disorders', 'Diabetes mellitus without mention of complication, type I [juvenile type], uncontrolled', 'Inflammatory disease of ovary, Fallopian tube, pelvic cellular tissue and peritoneum', 'Diabetes with ketoacidosis, type II or unspecified type, uncontrolled', 'Nonspecific findings on examination of blood', 'Certain adverse effects not elsewhere classified', 'Other forms of chronic ischaemic heart disease', 'Intervertebral disk disorders', 'Pneumonia, organism unspecified', 'Symptoms involving nervous and musculoskeletal systems', 'Diabetes mellitus without mention of complication, type II or unspecified type, uncontrolled', 'Pneumonia, organism unspecified', 'Fracture of rib(s), sternum, larynx and trachea', 'Pneumonia, organism unspecified', 'Transient cerebral ischaemia', 'Heart failure', 'Benign neoplasm of other endocrine glands and related structures', 'Contusion of lower limb and of other and unspecified sites', 'Hypertensive renal disease', 'Acute pulmonary heart disease', 'Disorders of the orbit', 'Diabetes with neurological manifestations, type II or unspecified type, not stated as uncontrolled', 'Other hernia of abdominal cavity without mention of obstruction or gangrene', 'Asthma', 'Diabetes with ketoacidosis, type II or unspecified type, not stated as uncontrolled', 'Pneumonia, organism unspecified', 'Diabetes with other specified manifestations, type II or unspecified type, not stated as uncontrolled', 'Other forms of chronic ischaemic heart disease', 'Cholelithiasis', 'Care involving use of rehabilitation procedures', 'Diabetes with peripheral circulatory disorders, type II or unspecified type, not stated as uncontrolled', 'Osteo-arthrosis and allied disorders', 'Fracture of rib(s), sternum, larynx and trachea', 'Acute myocardial infarction', 'Chronic bronchitis', 'Heart failure', 'Diseases of pancreas', 'Other current conditions in the mother classifiable elsewhere but complicating pregnancy, childbirth and the puerperium', 'Disorders of fluid, electrolyte and acid-base balance', 'Osteomyelitis, periostitis and other infections involving bone', 'Gastritis and duodenitis', 'Disorders of fluid, electrolyte and acid-base balance', 'Hypotension', 'Diabetes with other specified manifestations, type II or unspecified type, not stated as uncontrolled', 'Other organic psychotic conditions (chronic)', 'Other forms of chronic ischaemic heart disease', 'Injury, other and unspecified', 'Malignant neoplasm of colon', 'Other forms of chronic ischaemic heart disease', 'Diverticula of intestine', 'Cardiac dysrhythmias', 'Bacterial meningitis', 'Genital prolapse', 'Other forms of chronic ischaemic heart disease', 'Symptoms involving respiratory system and other chest symptoms', 'Heart failure', 'Acute but ill-defined cerebrovascular disease', 'Occlusion of cerebral arteries', 'Septicaemia', 'Pneumonia, organism unspecified', 'Diabetes with neurological manifestations, type II or unspecified type, not stated as uncontrolled', 'Heart failure', 'Diabetes with neurological manifestations, type II or unspecified type, not stated as uncontrolled', 'Asthma', 'Pneumonia, organism unspecified', 'Osteo-arthrosis and allied disorders', 'Other forms of chronic ischaemic heart disease', 'Acute pericarditis', 'Benign neoplasm of ovary', 'Transient cerebral ischaemia', 'Gastro-intestinal haemorrhage', 'Malignant neoplasm of bladder', 'Heart failure', 'Chronic bronchitis', 'Diseases of oesophagus', 'Cardiac dysrhythmias', 'Bron ...
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3787243235.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Description'] = description
#         encounter_id  patient_nbr       race  gender  age  admission_type_id  \
# 20737       72848634     20377854  Caucasian  Female   65                  2
# 20824       73062156     20408121  Caucasian  Female   95                  1
# 21083       73731852     20542797  Caucasian    Male   75                  1
# 23879       81355914      7239654  Caucasian  Female   75                  1
# 23922       81458964     15466212  Caucasian    Male   75                  1
# ...              ...          ...        ...     ...  ...                ...
# 101249     436785812     87833862  Caucasian    Male   75                  2
# 101268     437270768    124367945  Caucasian    Male   65                  1
# 101278     437309498     52653654  Caucasian    Male   65                  1
# 101284     437331638    142026269  Caucasian    Male   85                  2
# 101286     437331728     46488123  Caucasian  Female   85                  2
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# 20737                          1                    1                 3
# 20824                          1                    7                 4
# 21083                          2                    7                10
# 23879                          3                    6                12
# 23922                          3                    6                12
# ...                          ...                  ...               ...
# 101249                         3                    1                10
# 101268                         1                    7                 2
# 101278                         1                    7                 7
# 101284                         1                    4                 3
# 101286                         1                    1                 2
#
#        payer_code  ... glimepiride  glipizide  glyburide  pioglitazone  \
# 20737          MC  ...          No         No         No            No
# 20824          MC  ...      Steady         No         No            No
# 21083          MC  ...          No         No         No            No
# 23879          UN  ...          No         No         No            No
# 23922          MC  ...          No         No         No            No
# ...           ...  ...         ...        ...        ...           ...
# 101249         MC  ...          No         No         No            No
# 101268         OG  ...          No         No         No            No
# 101278         BC  ...          No         No         No            No
# 101284         MC  ...          No         No         No        Steady
# 101286         MC  ...          No         No         No            No
#
#         rosiglitazone  insulin  change diabetesMed readmitted  \
# 20737              No   Steady      No         Yes         NO
# 20824              No       No      No         Yes         NO
# 21083              No   Steady      Ch         Yes         NO
# 23879              No   Steady      No         Yes         NO
# 23922              No       No      No          No         NO
# ...               ...      ...     ...         ...        ...
# 101249             No     Down      Ch         Yes         NO
# 101268             No       Up      Ch         Yes         NO
# 101278             No       No      No         Yes         NO
# 101284             No       Up      Ch         Yes         NO
# 101286             No       No      No          No         NO
#
#                                               Description
# 20737           Aftercare involving intermittent dialysis
# 20824                                      Duodenal ulcer
# 21083                        Other cellulitis and abscess
# 23879   Neoplasm of uncertain behaviour of other and u...
# 23922                                      Duodenal ulcer
# ...                                                   ...
# 101249                        Malignant neoplasm of brain
# 101268                        Acute myocardial infarction
# 101278  Other hernia of abdominal cavity with obstruct...
# 101284                                 Chronic bronchitis
# 101286     Other forms of chronic ischaemic heart disease
#
# [17507 rows x 34 columns]

# %%
icd.shape
# Out:
# (1227, 2)

# %% [markdown]
# ## a. Age has a higher impact on readmission

# %%
# Age relate to readmitting


re1 = df[df['readmitted'] == ">30"]
re2 = df[df['readmitted'] == "<30"]
re3 = df[df['readmitted'] == "NO"]


Percentage_bigger30 = re1.groupby('age')['readmitted'].count().reset_index()
Percentage_smaller30 = re2.groupby('age')['readmitted'].count().reset_index()
Percentage_no = re3.groupby('age')['readmitted'].count().reset_index()

Percentage_Readmitted = df.groupby('age')['readmitted'].count().reset_index()
Percentage_Readmitted['>30 Percentage'] = 100 * Percentage_bigger30['readmitted']  / Percentage_Readmitted['readmitted']
Percentage_Readmitted['<30 Percentage'] = 100 * Percentage_smaller30['readmitted']  / Percentage_Readmitted['readmitted']
Percentage_Readmitted['No'] = 100 * Percentage_no['readmitted']  / Percentage_Readmitted['readmitted']


#totalss['Percentage'] = 100 * totalss['readmitted']  / totalss['readmitted'].sum()

#Percentage_Readmitted = combined.groupby('age')['readmitted'].count().reset_index()
#Percentage_Readmitted['Percentage'] = 100 * Percentage_Readmitted['readmitted']  / Percentage_Readmitted['readmitted']
#df.loc[df.age == 25, 'readmitted'].count()

y_data = {">30 Percentage","<30 Percentage"}

print(Percentage_Readmitted)

Percentage_Readmitted.plot.bar(stacked=True, y=y_data, x="age", rot=70, title="Age relate to readmitting");
# Out:
#    age  readmitted  >30 Percentage  <30 Percentage         No
# 0   25         288       22.222222        5.555556  72.222222
# 1   35         645       22.325581        6.356589  71.317829
# 2   45        1684       25.950119        6.175772  67.874109
# 3   55        3053       26.891582        6.714707  66.393711
# 4   65        3963       29.977290        7.696190  62.326520
# 5   75        4452       31.648697        8.647799  59.703504
# 6   85        2923       32.500855        9.955525  57.543620
# 7   95         499       24.649299       10.020040  65.330661
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/2231973654.py:29: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   Percentage_Readmitted.plot.bar(stacked=True, y=y_data, x="age", rot=70, title="Age relate to readmitting");

# %% [markdown]
# ## b. African Americans are more likely to be re-admitted than other ethnic groups.

# %%
Percentage_bigger30 = re1.groupby('race')['readmitted'].count().reset_index()
Percentage_smaller30 = re2.groupby('race')['readmitted'].count().reset_index()
Percentage_no = re3.groupby('race')['readmitted'].count().reset_index()

Percentage_Readmitted = df.groupby('race')['readmitted'].count().reset_index()
Percentage_Readmitted['>30 Percentage'] = 100 * Percentage_bigger30['readmitted']  / Percentage_Readmitted['readmitted']
Percentage_Readmitted['<30 Percentage'] = 100 * Percentage_smaller30['readmitted']  / Percentage_Readmitted['readmitted']
Percentage_Readmitted['No'] = 100 * Percentage_no['readmitted']  / Percentage_Readmitted['readmitted']


#totalss['Percentage'] = 100 * totalss['readmitted']  / totalss['readmitted'].sum()

#Percentage_Readmitted = combined.groupby('age')['readmitted'].count().reset_index()
#Percentage_Readmitted['Percentage'] = 100 * Percentage_Readmitted['readmitted']  / Percentage_Readmitted['readmitted']
#df.loc[df.age == 25, 'readmitted'].count()

y_data = {">30 Percentage","<30 Percentage"}

print(Percentage_Readmitted)

Percentage_Readmitted.plot.bar(stacked=True, y=y_data, x="race", rot=70, title="Race relate to readmitting");
# Out:
#               race  readmitted  >30 Percentage  <30 Percentage         No
# 0  AfricanAmerican        3515       24.637269        8.392603  66.970128
# 1            Asian         145       27.586207        6.206897  66.206897
# 2        Caucasian       13211       30.694119        7.985769  61.320112
# 3         Hispanic         331       25.377644        5.740181  68.882175
# 4            Other         305       29.836066        6.229508  63.934426
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/1055665950.py:21: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   Percentage_Readmitted.plot.bar(stacked=True, y=y_data, x="race", rot=70, title="Race relate to readmitting");

# %% [markdown]
# ## c. Women patients are more likely to be re-admitted than men.

# %%
Percentage_bigger30 = re1.groupby('gender')['readmitted'].count().reset_index()
Percentage_smaller30 = re2.groupby('gender')['readmitted'].count().reset_index()
Percentage_no = re3.groupby('gender')['readmitted'].count().reset_index()

Percentage_Readmitted = df.groupby('gender')['readmitted'].count().reset_index()
Percentage_Readmitted['>30 Percentage'] = 100 * Percentage_bigger30['readmitted']  / Percentage_Readmitted['readmitted']
Percentage_Readmitted['<30 Percentage'] = 100 * Percentage_smaller30['readmitted']  / Percentage_Readmitted['readmitted']
Percentage_Readmitted['No'] = 100 * Percentage_no['readmitted']  / Percentage_Readmitted['readmitted']


#totalss['Percentage'] = 100 * totalss['readmitted']  / totalss['readmitted'].sum()

#Percentage_Readmitted = combined.groupby('age')['readmitted'].count().reset_index()
#Percentage_Readmitted['Percentage'] = 100 * Percentage_Readmitted['readmitted']  / Percentage_Readmitted['readmitted']
#df.loc[df.age == 25, 'readmitted'].count()

y_data = {">30 Percentage","<30 Percentage"}

print(Percentage_Readmitted)

Percentage_Readmitted.plot.bar(stacked=True, y=y_data, x="gender", rot=70, title="Gender relate to readmitting");
# Out:
#    gender  readmitted  >30 Percentage  <30 Percentage         No
# 0  Female        9371       29.601964        8.014086  62.383950
# 1    Male        8136       29.031465        7.940020  63.028515
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/250596339.py:21: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   Percentage_Readmitted.plot.bar(stacked=True, y=y_data, x="gender", rot=70, title="Gender relate to readmitting");

# %% [markdown]
# ## d. Diagnose types have a higher impact on re-admission rates. For this purpose, you need to take into account the icd_codes and plot say diag_1 vs readmitted.

# %%
# diag relate to readmitting

re1 = df[df['readmitted'] == ">30"]
re2 = df[df['readmitted'] == "<30"]
re3 = df[df['readmitted'] == "NO"]


Percentage_bigger30 = re1.groupby('Description')['readmitted'].count().reset_index()
Percentage_smaller30 = re2.groupby('Description')['readmitted'].count().reset_index()
Percentage_no = re3.groupby('Description')['readmitted'].count().reset_index()

Percentage_Readmitted = df.groupby('Description')['readmitted'].count().reset_index()
Percentage_Readmitted2 = df.groupby('diag_1')['readmitted'].count().reset_index()

#check all missing Description value and fill with 0
for index, row in Percentage_Readmitted.iterrows():
    diag = Percentage_Readmitted.Description[index]
    if diag not in Percentage_bigger30['Description'].values:
        Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
    if diag not in Percentage_smaller30['Description'].values:
        Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
    if diag not in Percentage_no['Description'].values:
        Percentage_no = Percentage_no.append({'Description': diag,'readmitted' : 0}, ignore_index=True)

#sort the list and reset the index for the average calculation
Percentage_bigger30['Description'] = Percentage_bigger30['Description'].astype(str)
Percentage_bigger30 = Percentage_bigger30.sort_values('Description').reset_index()
Percentage_smaller30['Description'] = Percentage_smaller30['Description'].astype(str)
Percentage_smaller30 = Percentage_smaller30.sort_values('Description').reset_index()
Percentage_no['Description'] = Percentage_no['Description'].astype(str)
Percentage_no = Percentage_no.sort_values('Description').reset_index()

Percentage_Readmitted['>30 Percentage'] = 100 * Percentage_bigger30['readmitted']  / Percentage_Readmitted['readmitted']
Percentage_Readmitted['<30 Percentage'] = 100 * Percentage_smaller30['readmitted']  / Percentage_Readmitted['readmitted']
Percentage_Readmitted['No'] = 100 * Percentage_no['readmitted']  / Percentage_Readmitted['readmitted']


#totalss['Percentage'] = 100 * totalss['readmitted']  / totalss['readmitted'].sum()

#Percentage_Readmitted = combined.groupby('age')['readmitted'].count().reset_index()
#Percentage_Readmitted['Percentage'] = 100 * Percentage_Readmitted['readmitted']  / Percentage_Readmitted['readmitted']
#df.loc[df.age == 25, 'readmitted'].count()

y_data = {">30 Percentage","<30 Percentage"}
# Out:
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_no = Percentage_no.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_no = Percentage_no.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_no = Percentage_no.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_no = Percentage_no.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_no = Percentage_no.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_no = Percentage_no.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_no = Percentage_no.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_no = Percentage_no.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_no = Percentage_no.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_no = Percentage_no.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_no = Percentage_no.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_no = Percentage_no.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_no = Percentage_no.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_no = Percentage_no.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# ...
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_no = Percentage_no.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_no = Percentage_no.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_no = Percentage_no.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_no = Percentage_no.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_smaller30 = Percentage_smaller30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_no = Percentage_no.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_bigger30 = Percentage_bigger30.append({'Description': diag,'readmitted' : 0}, ignore_index=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/3835568573.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Percentage_no = Percentage_no.append({'Description': diag,'readmitted' : 0}, ignore_index=True)

# %%
print(Percentage_Readmitted)

#537 rows here, probably some description are same, all row with description only have 534 rows
#print(Percentage_Readmitted2)
# Out:
#                                            Description  readmitted  \
# 0                      Abnormality of forces of labour           9
# 1     Abnormality of organs and soft tissues of pelvis          15
# 2                   Abscess of anal and rectal regions          19
# 3                      Abscess of lung and mediastinum           5
# 4                          Acquired deformities of toe           2
# ..                                                 ...         ...
# 529  Vertiginous syndromes and other disorders of v...          19
# 530  Viral and chlamydial infection in conditions c...          12
# 531                                    Viral hepatitis           3
# 532                                    Viral pneumonia           1
# 533                                Visual disturbances           1
#
#      >30 Percentage  <30 Percentage         No
# 0         11.111111             0.0  88.888889
# 1          6.666667             0.0  93.333333
# 2         42.105263             0.0  57.894737
# 3         40.000000            20.0  40.000000
# 4         50.000000             0.0  50.000000
# ..              ...             ...        ...
# 529       15.789474             0.0  84.210526
# 530       25.000000             0.0  75.000000
# 531       33.333333             0.0  66.666667
# 532      100.000000             0.0   0.000000
# 533        0.000000           100.0   0.000000
#
# [534 rows x 5 columns]

# %%
print(Percentage_bigger30)
print(Percentage_smaller30)
print(Percentage_no)
# Out:
#      index                                        Description  readmitted
# 0        0                    Abnormality of forces of labour           1
# 1        1   Abnormality of organs and soft tissues of pelvis           1
# 2        2                 Abscess of anal and rectal regions           8
# 3        3                    Abscess of lung and mediastinum           2
# 4        4                        Acquired deformities of toe           1
# ..     ...                                                ...         ...
# 529    360  Vertiginous syndromes and other disorders of v...           3
# 530    361  Viral and chlamydial infection in conditions c...           3
# 531    362                                    Viral hepatitis           1
# 532    363                                    Viral pneumonia           1
# 533    533                                Visual disturbances           0
#
# [534 rows x 3 columns]
#      index                                        Description  readmitted
# 0      233                    Abnormality of forces of labour           0
# 1      234   Abnormality of organs and soft tissues of pelvis           0
# 2      235                 Abscess of anal and rectal regions           0
# 3        0                    Abscess of lung and mediastinum           1
# 4      236                        Acquired deformities of toe           0
# ..     ...                                                ...         ...
# 529    530  Vertiginous syndromes and other disorders of v...           0
# 530    531  Viral and chlamydial infection in conditions c...           0
# 531    532                                    Viral hepatitis           0
# 532    533                                    Viral pneumonia           0
# 533    232                                Visual disturbances           1
#
# [534 rows x 3 columns]
#      index                                        Description  readmitted
# 0        0                    Abnormality of forces of labour           8
# 1        1   Abnormality of organs and soft tissues of pelvis          14
# 2        2                 Abscess of anal and rectal regions          11
# 3        3                    Abscess of lung and mediastinum           2
# 4        4                        Acquired deformities of toe           1
# ..     ...                                                ...         ...
# 529    485  Vertiginous syndromes and other disorders of v...          16
# 530    486  Viral and chlamydial infection in conditions c...           9
# 531    487                                    Viral hepatitis           2
# 532    532                                    Viral pneumonia           0
# 533    533                                Visual disturbances           0
#
# [534 rows x 3 columns]

# %%
#analysing data and filtering data to avoid outliers
Percentage_Readmitted.describe()
# Out:
#         readmitted  >30 Percentage  <30 Percentage          No
# count   534.000000      534.000000      534.000000  534.000000
# mean     32.784644       25.615800        7.166257   67.217944
# std     102.677661       26.059854       14.690827   28.446964
# min       1.000000        0.000000        0.000000    0.000000
# 25%       2.000000        0.000000        0.000000   53.873824
# 50%       5.000000       25.000000        0.000000   66.666667
# 75%      19.000000       36.111450        9.195804  100.000000
# max    1303.000000      100.000000      100.000000  100.000000

# %%
no_readmission = Percentage_Readmitted.plot.scatter(x="readmitted", y="No", color="Green", label="Percentage of no readmitting compare to all patient")

smaller = Percentage_Readmitted.plot.scatter(x="readmitted", y="<30 Percentage", color="Red", label="Percentage of <30 readmitting compare to all patient", ax=no_readmission)

bigger = Percentage_Readmitted.plot.scatter(x="readmitted", y=">30 Percentage", color="Blue", label="Percentage of >30 readmitting compare to all patient", ax=no_readmission, figsize=(20, 15))

bigger.set_xlabel("Total Readmission number of each type of diag_1")
bigger.set_ylabel("Percentage")
# Out:
# Text(0, 0.5, 'Percentage')

# %%
#Removing outliers to make a cleaner dataset
Percentage_Readmitted = Percentage_Readmitted[(Percentage_Readmitted['No'] >= 20) & (Percentage_Readmitted['No'] <= 95)]
Percentage_Readmitted = Percentage_Readmitted[(Percentage_Readmitted['readmitted'] <= 250)]

no_readmission = Percentage_Readmitted.plot.scatter(x="readmitted", y="No", color="Green", label="Percentage of no readmitting compare to all patient", figsize=(20, 15))
#Removing outliers to make a cleaner dataset
Percentage_Readmitted = Percentage_Readmitted[(Percentage_Readmitted['<30 Percentage'] <= 25)]
Percentage_Readmitted = Percentage_Readmitted[(Percentage_Readmitted['readmitted'] <= 250)]
#
smaller = Percentage_Readmitted.plot.scatter(x="readmitted", y="<30 Percentage", color="Red", label="Percentage of <30 readmitting compare to all patient", figsize=(20, 15), ax=no_readmission)
#Removing outliers to make a cleaner dataset
Percentage_Readmitted = Percentage_Readmitted[(Percentage_Readmitted['>30 Percentage'] <= 60)]
bigger = Percentage_Readmitted.plot.scatter(x="readmitted", y=">30 Percentage", color="Blue", label="Percentage of >30 readmitting compare to all patient", figsize=(20, 15), ax=no_readmission)

bigger.set_xlabel("Total Readmission number of each type of diag_1")
bigger.set_ylabel("Percentage")

smaller.set_xlabel("Total Readmission number of each type of diag_1")
smaller.set_ylabel("Percentage")

no_readmission.set_xlabel("Total Readmission number of each type of diag_1")
no_readmission.set_ylabel("Percentage")
# Out:
# Text(0, 0.5, 'Percentage')

# %% [markdown]
# # <font color=red>1.3 Modelling</font>

# %%
subset = ['num_medications', 'number_outpatient', 'number_emergency', 'time_in_hospital', 'number_inpatient', 'encounter_id', 'age', 'num_lab_procedures', 'number_diagnoses', 'num_procedures', 'readmitted']

# %%
df[subset].dtypes
# Out:
# num_medications        int64
# number_outpatient      int64
# number_emergency       int64
# time_in_hospital       int64
# number_inpatient       int64
# encounter_id           int64
# age                    int64
# num_lab_procedures     int64
# number_diagnoses       int64
# num_procedures         int64
# readmitted            object
# dtype: object

# %%
df[subset[:-1]]
# Out:
#         num_medications  number_outpatient  number_emergency  \
# 20737                11                  0                 0
# 20824                 9                  0                 0
# 21083                18                  0                 0
# 23879                19                  0                 0
# 23922                10                  0                 0
# ...                 ...                ...               ...
# 101249               19                  0                 0
# 101268               19                  0                 0
# 101278               14                  1                 0
# 101284               15                  0                 0
# 101286               13                  0                 0
#
#         time_in_hospital  number_inpatient  encounter_id  age  \
# 20737                  3                 0      72848634   65
# 20824                  4                 0      73062156   95
# 21083                 10                 0      73731852   75
# 23879                 12                 0      81355914   75
# 23922                 12                 0      81458964   75
# ...                  ...               ...           ...  ...
# 101249                10                 0     436785812   75
# 101268                 2                 0     437270768   65
# 101278                 7                 0     437309498   65
# 101284                 3                 1     437331638   85
# 101286                 2                 1     437331728   85
#
#         num_lab_procedures  number_diagnoses  num_procedures
# 20737                   59                 6               3
# 20824                   56                 6               1
# 21083                   68                 6               1
# 23879                   77                 5               5
# 23922                   60                 5               5
# ...                    ...               ...             ...
# 101249                  59                 9               1
# 101268                  53                 9               6
# 101278                  54                 2               4
# 101284                   1                 9               0
# 101286                  41                 6               3
#
# [17507 rows x 10 columns]

# %%
df['readmitted']
# Out:
# 20737     NO
# 20824     NO
# 21083     NO
# 23879     NO
# 23922     NO
#           ..
# 101249    NO
# 101268    NO
# 101278    NO
# 101284    NO
# 101286    NO
# Name: readmitted, Length: 17507, dtype: object

# %%
print(df['readmitted'].unique())
# print(df.groupby(['readmitted']).count())
# Out:
# ['NO' '>30' '<30']

# %%
df_readmitted = df['readmitted']
binary_readmitted = []

for x in df_readmitted:
    if x == 'NO':
        binary_readmitted.append(0)
    else:
        binary_readmitted.append(1)

df['binary_readmitted'] = binary_readmitted
df
# Out:
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/2373265820.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['binary_readmitted'] = binary_readmitted
#         encounter_id  patient_nbr       race  gender  age  admission_type_id  \
# 20737       72848634     20377854  Caucasian  Female   65                  2
# 20824       73062156     20408121  Caucasian  Female   95                  1
# 21083       73731852     20542797  Caucasian    Male   75                  1
# 23879       81355914      7239654  Caucasian  Female   75                  1
# 23922       81458964     15466212  Caucasian    Male   75                  1
# ...              ...          ...        ...     ...  ...                ...
# 101249     436785812     87833862  Caucasian    Male   75                  2
# 101268     437270768    124367945  Caucasian    Male   65                  1
# 101278     437309498     52653654  Caucasian    Male   65                  1
# 101284     437331638    142026269  Caucasian    Male   85                  2
# 101286     437331728     46488123  Caucasian  Female   85                  2
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# 20737                          1                    1                 3
# 20824                          1                    7                 4
# 21083                          2                    7                10
# 23879                          3                    6                12
# 23922                          3                    6                12
# ...                          ...                  ...               ...
# 101249                         3                    1                10
# 101268                         1                    7                 2
# 101278                         1                    7                 7
# 101284                         1                    4                 3
# 101286                         1                    1                 2
#
#        payer_code  ... glipizide  glyburide  pioglitazone  rosiglitazone  \
# 20737          MC  ...        No         No            No             No
# 20824          MC  ...        No         No            No             No
# 21083          MC  ...        No         No            No             No
# 23879          UN  ...        No         No            No             No
# 23922          MC  ...        No         No            No             No
# ...           ...  ...       ...        ...           ...            ...
# 101249         MC  ...        No         No            No             No
# 101268         OG  ...        No         No            No             No
# 101278         BC  ...        No         No            No             No
# 101284         MC  ...        No         No        Steady             No
# 101286         MC  ...        No         No            No             No
#
#         insulin  change  diabetesMed readmitted  \
# 20737    Steady      No          Yes         NO
# 20824        No      No          Yes         NO
# 21083    Steady      Ch          Yes         NO
# 23879    Steady      No          Yes         NO
# 23922        No      No           No         NO
# ...         ...     ...          ...        ...
# 101249     Down      Ch          Yes         NO
# 101268       Up      Ch          Yes         NO
# 101278       No      No          Yes         NO
# 101284       Up      Ch          Yes         NO
# 101286       No      No           No         NO
#
#                                               Description binary_readmitted
# 20737           Aftercare involving intermittent dialysis                 0
# 20824                                      Duodenal ulcer                 0
# 21083                        Other cellulitis and abscess                 0
# 23879   Neoplasm of uncertain behaviour of other and u...                 0
# 23922                                      Duodenal ulcer                 0
# ...                                                   ...               ...
# 101249                        Malignant neoplasm of brain                 0
# 101268                        Acute myocardial infarction                 0
# 101278  Other hernia of abdominal cavity with obstruct...                 0
# 101284                                 Chronic bronchitis                 0
# 101286     Other forms of chronic ischaemic heart disease                 0
#
# [17507 rows x 35 columns]

# %%
df.dtypes
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                          int64
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# payer_code                  object
# medical_specialty           object
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# glimepiride                 object
# glipizide                   object
# glyburide                   object
# pioglitazone                object
# rosiglitazone               object
# insulin                     object
# change                      object
# diabetesMed                 object
# readmitted                  object
# Description                 object
# binary_readmitted            int64
# dtype: object

# %%
(unique, counts) = np.unique(df['binary_readmitted'], return_counts=True)
print(unique, counts)
plt.bar(unique, counts)
plt.ylabel('Frequency: not readmitted vs readmitted')
plt.title('Histogram: target variable counts in dataset')
plt.show()
# Out:
# [0 1] [10974  6533]

# %%
def readmitted_boxplot(df, columns):
    for col in df[columns]:
        # print(col)
        fig = plt.figure(figsize=(6, 6))
        fig.clf()
        ax = fig.gca()
        df.boxplot(column=[col], ax=ax, by=['binary_readmitted'])
        plt.show()
    return('Done')
readmitted_boxplot(df, subset[:-1])
# Out:
# 'Done'

# %%
def readmitted_scatter(df, columns):
    for col in df[columns]:
        # print(col)
        fig = plt.figure(figsize=(7, 7))
        fig.clf()
        ax = fig.gca()
        df.plot(kind='scatter', x=[col], ax=ax, y='binary_readmitted')
        plt.show()
    return('Done')
# readmitted_scatter(df, list(selected_features))

# %%
#best features selection
#
from sklearn import linear_model, feature_selection

model = linear_model.LogisticRegression()
X0 = df.loc[:, subset[:-1]]
Y0 = df['binary_readmitted']
selector = feature_selection.RFE(model, n_features_to_select=7, step=1)     #from the box plot deducted the best ones to use
selector = selector.fit(X0, Y0)
selected_features = X0.loc[:, selector.support_]
print("Selected features:\n{}".format(',\n'.join(list(selected_features))))
# Out:
# Selected features:
# num_medications,
# time_in_hospital,
# encounter_id,
# age,
# num_lab_procedures,
# number_diagnoses,
# num_procedures

# %%
#normalise the data for independent variables

df_norm = df[list(selected_features)]
df_norm = (df_norm - df_norm.min()) / (df_norm.max() - df_norm.min())
df_norm.describe()
# Out:
#        num_medications  time_in_hospital  encounter_id           age  \
# count     17507.000000      17507.000000  17507.000000  17507.000000
# mean          0.354424          0.253142      0.291870      0.590090
# std           0.184741          0.230093      0.218686      0.217391
# min           0.000000          0.000000      0.000000      0.000000
# 25%           0.225000          0.083333      0.126069      0.428571
# 50%           0.325000          0.166667      0.230825      0.571429
# 75%           0.475000          0.333333      0.411855      0.714286
# max           1.000000          1.000000      1.000000      1.000000
#
#        num_lab_procedures  number_diagnoses  num_procedures
# count        17507.000000      17507.000000    17507.000000
# mean             0.403393          0.460834        0.247101
# std              0.198088          0.180315        0.292018
# min              0.000000          0.000000        0.000000
# 25%              0.292929          0.272727        0.000000
# 50%              0.414141          0.545455        0.166667
# 75%              0.535354          0.636364        0.333333
# max              1.000000          1.000000        1.000000

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

#train data
X = df_norm
y = df['binary_readmitted']

X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.25, random_state=0)

# Build up the logistic model with training set
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn import metrics
from sklearn.model_selection import cross_val_score
X = df_norm
Y = df['binary_readmitted']
trainX, testX, trainY, testY = train_test_split(X, Y, test_size=0.3, random_state=0)
clf = linear_model.LogisticRegression()
clf.fit(trainX, trainY)
predicted = clf.predict(testX)

print("Mean hits: {}".format(np.mean(predicted==testY)))
print("Accuracy score: {}".format(metrics.accuracy_score(testY, predicted)))
scores = cross_val_score(linear_model.LogisticRegression(), X, Y, scoring='accuracy', cv=10)
print("Cross validation mean scores: {}".format(scores.mean()))
# Out:
# Mean hits: 0.6293546544831525
# Accuracy score: 0.6293546544831525
# Cross validation mean scores: 0.6298620543362977

# %%
from sklearn.metrics import accuracy_score

##Evaluation

# predict the outcome for the test data
pred_test = model.predict(X_test)
pred_train = model.predict(X_train)     #to check if train match with test

accuracy_train = accuracy_score(pred_train, y_train)
print('Accuracy for the training set = {:0.3f}'.format(accuracy_train))
## Acuracy score for the test data
accuracy_test = accuracy_score(pred_test, y_test)
print('Accuracy for the test set = {:0.3f}'.format(accuracy_test))
# Out:
# Accuracy for the training set = 0.635
# Accuracy for the test set = 0.628

# %%
from sklearn.metrics import confusion_matrix

# confusion matrix for the test data: it is the matrix that come with TP, TN, FN, FP
pred = pred_test
cm = confusion_matrix(y_test, pred)

TN, FP, FN, TP = confusion_matrix(y_test, pred_test).ravel()

print('True Positive(TP)  = ', TP)
print('False Positive(FP) = ', FP)
print('True Negative(TN)  = ', TN)
print('False Negative(FN) = ', FN)

accuracy =  (TP+TN) /(TP+FP+TN+FN)

print('Accuracy of the binary classification = {:0.3f}'.format(accuracy))
# Out:
# True Positive(TP)  =  238
# False Positive(FP) =  187
# True Negative(TN)  =  2510
# False Negative(FN) =  1442
# Accuracy of the binary classification = 0.628

# %%
print(cm)
# Out:
# [[2510  187]
#  [1442  238]]

# %%
from sklearn.metrics import classification_report

classification_report(y_test, pred_test)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.64      0.93      0.76      2697\n           1       0.56      0.14      0.23      1680\n\n    accuracy                           0.63      4377\n   macro avg       0.60      0.54      0.49      4377\nweighted avg       0.61      0.63      0.55      4377\n'

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test, pred)
# Out:
# 0.5361651835372636

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_predictions(y_test, pred)
plt.show()

# %% [markdown]
# # <font color=red>Improved model</font>

# %%
df.head(5)
# Out:
#        encounter_id  patient_nbr       race  gender  age  admission_type_id  \
# 20737      72848634     20377854  Caucasian  Female   65                  2
# 20824      73062156     20408121  Caucasian  Female   95                  1
# 21083      73731852     20542797  Caucasian    Male   75                  1
# 23879      81355914      7239654  Caucasian  Female   75                  1
# 23922      81458964     15466212  Caucasian    Male   75                  1
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# 20737                         1                    1                 3
# 20824                         1                    7                 4
# 21083                         2                    7                10
# 23879                         3                    6                12
# 23922                         3                    6                12
#
#       payer_code  ... glipizide  glyburide  pioglitazone  rosiglitazone  \
# 20737         MC  ...        No         No            No             No
# 20824         MC  ...        No         No            No             No
# 21083         MC  ...        No         No            No             No
# 23879         UN  ...        No         No            No             No
# 23922         MC  ...        No         No            No             No
#
#        insulin  change  diabetesMed readmitted  \
# 20737   Steady      No          Yes         NO
# 20824       No      No          Yes         NO
# 21083   Steady      Ch          Yes         NO
# 23879   Steady      No          Yes         NO
# 23922       No      No           No         NO
#
#                                              Description binary_readmitted
# 20737          Aftercare involving intermittent dialysis                 0
# 20824                                     Duodenal ulcer                 0
# 21083                       Other cellulitis and abscess                 0
# 23879  Neoplasm of uncertain behaviour of other and u...                 0
# 23922                                     Duodenal ulcer                 0
#
# [5 rows x 35 columns]

# %%
for column in df.columns:
    if column[-3:] == '_id':
        df.drop([column], axis=1, inplace=True)


df.drop(['patient_nbr'], axis=1, inplace=True)
df.drop(['readmitted'], axis=1, inplace=True)
df.drop(['number_emergency'], axis=1, inplace=True)

df
# Out:
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/1535867586.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop([column], axis=1, inplace=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/1535867586.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop([column], axis=1, inplace=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/1535867586.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop([column], axis=1, inplace=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/1535867586.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop([column], axis=1, inplace=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/1535867586.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['patient_nbr'], axis=1, inplace=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/1535867586.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['readmitted'], axis=1, inplace=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/1535867586.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['number_emergency'], axis=1, inplace=True)
#              race  gender  age  time_in_hospital payer_code medical_specialty  \
# 20737   Caucasian  Female   65                 3         MC        Nephrology
# 20824   Caucasian  Female   95                 4         MC  Emergency/Trauma
# 21083   Caucasian    Male   75                10         MC  InternalMedicine
# 23879   Caucasian  Female   75                12         UN  InternalMedicine
# 23922   Caucasian    Male   75                12         MC  InternalMedicine
# ...           ...     ...  ...               ...        ...               ...
# 101249  Caucasian    Male   75                10         MC  InternalMedicine
# 101268  Caucasian    Male   65                 2         OG  InternalMedicine
# 101278  Caucasian    Male   65                 7         BC   Surgery-General
# 101284  Caucasian    Male   85                 3         MC       Radiologist
# 101286  Caucasian  Female   85                 2         MC       Radiologist
#
#         num_lab_procedures  num_procedures  num_medications  \
# 20737                   59               3               11
# 20824                   56               1                9
# 21083                   68               1               18
# 23879                   77               5               19
# 23922                   60               5               10
# ...                    ...             ...              ...
# 101249                  59               1               19
# 101268                  53               6               19
# 101278                  54               4               14
# 101284                   1               0               15
# 101286                  41               3               13
#
#         number_outpatient  ...  glimepiride glipizide glyburide pioglitazone  \
# 20737                   0  ...           No        No        No           No
# 20824                   0  ...       Steady        No        No           No
# 21083                   0  ...           No        No        No           No
# 23879                   0  ...           No        No        No           No
# 23922                   0  ...           No        No        No           No
# ...                   ...  ...          ...       ...       ...          ...
# 101249                  0  ...           No        No        No           No
# 101268                  0  ...           No        No        No           No
# 101278                  1  ...           No        No        No           No
# 101284                  0  ...           No        No        No       Steady
# 101286                  0  ...           No        No        No           No
#
#         rosiglitazone insulin change diabetesMed  \
# 20737              No  Steady     No         Yes
# 20824              No      No     No         Yes
# 21083              No  Steady     Ch         Yes
# 23879              No  Steady     No         Yes
# 23922              No      No     No          No
# ...               ...     ...    ...         ...
# 101249             No    Down     Ch         Yes
# 101268             No      Up     Ch         Yes
# 101278             No      No     No         Yes
# 101284             No      Up     Ch         Yes
# 101286             No      No     No          No
#
#                                               Description binary_readmitted
# 20737           Aftercare involving intermittent dialysis                 0
# 20824                                      Duodenal ulcer                 0
# 21083                        Other cellulitis and abscess                 0
# 23879   Neoplasm of uncertain behaviour of other and u...                 0
# 23922                                      Duodenal ulcer                 0
# ...                                                   ...               ...
# 101249                        Malignant neoplasm of brain                 0
# 101268                        Acute myocardial infarction                 0
# 101278  Other hernia of abdominal cavity with obstruct...                 0
# 101284                                 Chronic bronchitis                 0
# 101286     Other forms of chronic ischaemic heart disease                 0
#
# [17507 rows x 28 columns]

# %%
df_gender = pd.get_dummies(df, columns=['gender'])
df.drop(['gender'], axis=1, inplace=True)
df['gender_Female'] = pd.to_numeric(df_gender['gender_Female'])

df_race = pd.get_dummies(df, columns=['race'])
df.drop(['race'], axis=1, inplace=True)
df['race_AfricanAmerican'] = pd.to_numeric(df_race['race_AfricanAmerican'])
df
# Out:
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/2264545343.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['gender'], axis=1, inplace=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/2264545343.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender_Female'] = pd.to_numeric(df_gender['gender_Female'])
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/2264545343.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['race'], axis=1, inplace=True)
# /var/folders/zv/93g4pj295dng6081ygj2bmb00000gn/T/ipykernel_79542/2264545343.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['race_AfricanAmerican'] = pd.to_numeric(df_race['race_AfricanAmerican'])
#         age  time_in_hospital payer_code medical_specialty  \
# 20737    65                 3         MC        Nephrology
# 20824    95                 4         MC  Emergency/Trauma
# 21083    75                10         MC  InternalMedicine
# 23879    75                12         UN  InternalMedicine
# 23922    75                12         MC  InternalMedicine
# ...     ...               ...        ...               ...
# 101249   75                10         MC  InternalMedicine
# 101268   65                 2         OG  InternalMedicine
# 101278   65                 7         BC   Surgery-General
# 101284   85                 3         MC       Radiologist
# 101286   85                 2         MC       Radiologist
#
#         num_lab_procedures  num_procedures  num_medications  \
# 20737                   59               3               11
# 20824                   56               1                9
# 21083                   68               1               18
# 23879                   77               5               19
# 23922                   60               5               10
# ...                    ...             ...              ...
# 101249                  59               1               19
# 101268                  53               6               19
# 101278                  54               4               14
# 101284                   1               0               15
# 101286                  41               3               13
#
#         number_outpatient  number_inpatient diag_1  ... glyburide  \
# 20737                   0                 0    V56  ...        No
# 20824                   0                 0    532  ...        No
# 21083                   0                 0    682  ...        No
# 23879                   0                 0    238  ...        No
# 23922                   0                 0    532  ...        No
# ...                   ...               ...    ...  ...       ...
# 101249                  0                 0    191  ...        No
# 101268                  0                 0    410  ...        No
# 101278                  1                 0    552  ...        No
# 101284                  0                 1    491  ...        No
# 101286                  0                 1    414  ...        No
#
#        pioglitazone  rosiglitazone insulin change diabetesMed  \
# 20737            No             No  Steady     No         Yes
# 20824            No             No      No     No         Yes
# 21083            No             No  Steady     Ch         Yes
# 23879            No             No  Steady     No         Yes
# 23922            No             No      No     No          No
# ...             ...            ...     ...    ...         ...
# 101249           No             No    Down     Ch         Yes
# 101268           No             No      Up     Ch         Yes
# 101278           No             No      No     No         Yes
# 101284       Steady             No      Up     Ch         Yes
# 101286           No             No      No     No          No
#
#                                               Description binary_readmitted  \
# 20737           Aftercare involving intermittent dialysis                 0
# 20824                                      Duodenal ulcer                 0
# 21083                        Other cellulitis and abscess                 0
# 23879   Neoplasm of uncertain behaviour of other and u...                 0
# 23922                                      Duodenal ulcer                 0
# ...                                                   ...               ...
# 101249                        Malignant neoplasm of brain                 0
# 101268                        Acute myocardial infarction                 0
# 101278  Other hernia of abdominal cavity with obstruct...                 0
# 101284                                 Chronic bronchitis                 0
# 101286     Other forms of chronic ischaemic heart disease                 0
#
#        gender_Female race_AfricanAmerican
# 20737              1                    0
# 20824              1                    0
# 21083              0                    0
# 23879              1                    0
# 23922              0                    0
# ...              ...                  ...
# 101249             0                    0
# 101268             0                    0
# 101278             0                    0
# 101284             0                    0
# 101286             1                    0
#
# [17507 rows x 28 columns]

# %%
from seaborn import pairplot

# pairplot(df)

# %%
# df.dtypes

# %%
# subset = subset[:-1]
# subset.remove('number_emergency')
# subset.append('binary_readmitted')
# df[subset].describe()

# %%
def trim(df):
    for features in df:
        ##mean = df[features].mean()
        mean = np.mean(df[features])
        std = np.std(df[features])
        df = df[(df[features] >= mean-(2*std)) & (df[features] <= mean+(2*std))]
    return df



df_trimmed = trim(df.select_dtypes(include=numerics))
# y = trim(y)
df_trimmed.describe()
# Out:
#                 age  time_in_hospital  num_lab_procedures  num_procedures  \
# count  11687.000000      11687.000000        11687.000000    11687.000000
# mean      68.513305          3.637717           42.287413        1.155985
# std       13.343703          2.138498           16.666221        1.395901
# min       45.000000          1.000000            2.000000        0.000000
# 25%       55.000000          2.000000           33.000000        0.000000
# 50%       65.000000          3.000000           43.000000        1.000000
# 75%       75.000000          5.000000           54.000000        2.000000
# max       95.000000          9.000000           78.000000        5.000000
#
#        num_medications  number_outpatient  number_inpatient  number_diagnoses  \
# count     11687.000000       11687.000000      11687.000000      11687.000000
# mean         14.023359           0.060323          0.106785          7.119620
# std           5.978287           0.238095          0.308853          1.827322
# min           1.000000           0.000000          0.000000          4.000000
# 25%          10.000000           0.000000          0.000000          5.000000
# 50%          14.000000           0.000000          0.000000          7.000000
# 75%          18.000000           0.000000          0.000000          9.000000
# max          28.000000           1.000000          1.000000          9.000000
#
#        binary_readmitted
# count       11687.000000
# mean            0.357662
# std             0.479333
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             1.000000
# max             1.000000

# %%
# readmitted_boxplot(df_trimmed, subset[:-1])

# %%
#normalise the data for independent variables

# df_trimmed.dropna('number_emergency', inplace=True)

# df_norm = df_trimmed[subset[:-1]]

df_norm = df_trimmed
df_norm = (df_norm - df_norm.min()) / (df_norm.max() - df_norm.min())
# df_norm.describe()

# %%
y = df_norm['binary_readmitted']
df_norm.drop(['binary_readmitted'], axis=1, inplace=True)
y
# Out:
# 20737     0.0
# 20824     0.0
# 24028     1.0
# 24137     0.0
# 24143     0.0
#          ...
# 101203    0.0
# 101233    1.0
# 101238    0.0
# 101240    1.0
# 101286    0.0
# Name: binary_readmitted, Length: 11687, dtype: float64

# %%
X = df_norm
X
# Out:
#         age  time_in_hospital  num_lab_procedures  num_procedures  \
# 20737   0.4             0.250            0.750000             0.6
# 20824   1.0             0.375            0.710526             0.2
# 24028   0.2             0.625            0.407895             0.2
# 24137   0.6             0.125            0.644737             0.0
# 24143   0.6             0.875            0.789474             0.0
# ...     ...               ...                 ...             ...
# 101203  1.0             0.250            0.881579             0.0
# 101233  0.8             0.250            0.368421             0.8
# 101238  0.6             0.000            0.881579             0.2
# 101240  1.0             0.500            0.236842             0.4
# 101286  0.8             0.125            0.513158             0.6
#
#         num_medications  number_outpatient  number_inpatient  number_diagnoses
# 20737          0.370370                0.0               0.0               0.4
# 20824          0.296296                0.0               0.0               0.4
# 24028          0.148148                0.0               0.0               0.2
# 24137          0.222222                0.0               0.0               0.2
# 24143          0.518519                0.0               0.0               0.2
# ...                 ...                ...               ...               ...
# 101203         0.222222                0.0               0.0               0.6
# 101233         0.444444                0.0               0.0               0.8
# 101238         0.703704                0.0               0.0               1.0
# 101240         0.444444                0.0               0.0               1.0
# 101286         0.444444                0.0               1.0               0.4
#
# [11687 rows x 8 columns]

# %%
#train data
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.25, random_state=0)

# Build up the logistic model with training set
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
##Evaluation

# predict the outcome for the test data
pred_test = model.predict(X_test)
pred_train = model.predict(X_train)     #to check if train match with test

accuracy_train = accuracy_score(pred_train, y_train)
print('Accuracy for the training set = {:0.3f}'.format(accuracy_train))
## Acuracy score for the test data
accuracy_test = accuracy_score(pred_test, y_test)
print('Accuracy for the test set = {:0.3f}'.format(accuracy_test))
# Out:
# Accuracy for the training set = 0.644
# Accuracy for the test set = 0.638

# %%
# confusion matrix for the test data: it is the matrix that come with TP, TN, FN, FP
pred = pred_test
cm = confusion_matrix(y_test, pred)

TN, FP, FN, TP = confusion_matrix(y_test, pred_test).ravel()

print('True Positive(TP)  = ', TP)
print('False Positive(FP) = ', FP)
print('True Negative(TN)  = ', TN)
print('False Negative(FN) = ', FN)

accuracy =  (TP+TN) /(TP+FP+TN+FN)

print('Accuracy of the binary classification = {:0.3f}'.format(accuracy))
# Out:
# True Positive(TP)  =  98
# False Positive(FP) =  100
# True Negative(TN)  =  1767
# False Negative(FN) =  957
# Accuracy of the binary classification = 0.638

# %%
print(cm)
print(classification_report(y_test, pred_test))
roc_auc_score(y_test, pred)
# Out:
# [[1767  100]
#  [ 957   98]]
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.95      0.77      1867
#          1.0       0.49      0.09      0.16      1055
#
#     accuracy                           0.64      2922
#    macro avg       0.57      0.52      0.46      2922
# weighted avg       0.59      0.64      0.55      2922
# 0.5196645656538991

# %%
RocCurveDisplay.from_predictions(y_test, pred)
plt.show()
