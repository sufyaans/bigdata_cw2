# %%
#Imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import datetime
from scipy.optimize import curve_fit
from scipy import stats
from IPython.display import display

# %%
#Loading the data
rawData = 'diabetic_data/diabetic_data/diabetic_data.csv'
rawData2 = 'diabetic_data/diabetic_data/icd_codes.csv'
icdCodes = pd.read_csv(rawData2)
df = pd.read_csv(rawData)
df
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                       6                        25                    1
# 1                       1                         1                    7
# 2                       1                         1                    7
# 3                       1                         1                    7
# 4                       1                         1                    7
# ...                   ...                       ...                  ...
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 0                      1  ...          No      No                   No
# 1                      3  ...          No      Up                   No
# 2                      2  ...          No      No                   No
# 3                      2  ...          No      Up                   No
# 4                      1  ...          No  Steady                   No
# ...                  ...  ...         ...     ...                  ...
# 101761                 3  ...          No    Down                   No
# 101762                 5  ...          No  Steady                   No
# 101763                 1  ...          No    Down                   No
# 101764                10  ...          No      Up                   No
# 101765                 6  ...          No      No                   No
#
#         glipizide-metformin  glimepiride-pioglitazone  \
# 0                        No                        No
# 1                        No                        No
# 2                        No                        No
# 3                        No                        No
# 4                        No                        No
# ...                     ...                       ...
# 101761                   No                        No
# 101762                   No                        No
# 101763                   No                        No
# 101764                   No                        No
# 101765                   No                        No
#
#         metformin-rosiglitazone  metformin-pioglitazone  change diabetesMed  \
# 0                            No                      No      No          No
# 1                            No                      No      Ch         Yes
# 2                            No                      No      No         Yes
# 3                            No                      No      Ch         Yes
# 4                            No                      No      Ch         Yes
# ...                         ...                     ...     ...         ...
# 101761                       No                      No      Ch         Yes
# 101762                       No                      No      No         Yes
# 101763                       No                      No      Ch         Yes
# 101764                       No                      No      Ch         Yes
# 101765                       No                      No      No          No
#
#        readmitted
# 0              NO
# 1             >30
# 2              NO
# 3              NO
# 4              NO
# ...           ...
# 101761        >30
# 101762         NO
# 101763         NO
# 101764         NO
# 101765         NO
#
# [101766 rows x 50 columns]

# %%
#Shows the shape of the dataset
df.shape
# Out:
# (101766, 50)

# %%
#replacing the missing values with numpy.NaN
df_2 = df.replace('?', np.NaN)
df_2
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)    NaN
# 1             149190     55629189        Caucasian  Female  [10-20)    NaN
# 2              64410     86047875  AfricanAmerican  Female  [20-30)    NaN
# 3             500364     82442376        Caucasian    Male  [30-40)    NaN
# 4              16680     42519267        Caucasian    Male  [40-50)    NaN
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)    NaN
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)    NaN
# 101763     443854148     41088789        Caucasian    Male  [70-80)    NaN
# 101764     443857166     31693671        Caucasian  Female  [80-90)    NaN
# 101765     443867222    175429310        Caucasian    Male  [70-80)    NaN
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                       6                        25                    1
# 1                       1                         1                    7
# 2                       1                         1                    7
# 3                       1                         1                    7
# 4                       1                         1                    7
# ...                   ...                       ...                  ...
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 0                      1  ...          No      No                   No
# 1                      3  ...          No      Up                   No
# 2                      2  ...          No      No                   No
# 3                      2  ...          No      Up                   No
# 4                      1  ...          No  Steady                   No
# ...                  ...  ...         ...     ...                  ...
# 101761                 3  ...          No    Down                   No
# 101762                 5  ...          No  Steady                   No
# 101763                 1  ...          No    Down                   No
# 101764                10  ...          No      Up                   No
# 101765                 6  ...          No      No                   No
#
#         glipizide-metformin  glimepiride-pioglitazone  \
# 0                        No                        No
# 1                        No                        No
# 2                        No                        No
# 3                        No                        No
# 4                        No                        No
# ...                     ...                       ...
# 101761                   No                        No
# 101762                   No                        No
# 101763                   No                        No
# 101764                   No                        No
# 101765                   No                        No
#
#         metformin-rosiglitazone  metformin-pioglitazone  change diabetesMed  \
# 0                            No                      No      No          No
# 1                            No                      No      Ch         Yes
# 2                            No                      No      No         Yes
# 3                            No                      No      Ch         Yes
# 4                            No                      No      Ch         Yes
# ...                         ...                     ...     ...         ...
# 101761                       No                      No      Ch         Yes
# 101762                       No                      No      No         Yes
# 101763                       No                      No      Ch         Yes
# 101764                       No                      No      Ch         Yes
# 101765                       No                      No      No          No
#
#        readmitted
# 0              NO
# 1             >30
# 2              NO
# 3              NO
# 4              NO
# ...           ...
# 101761        >30
# 101762         NO
# 101763         NO
# 101764         NO
# 101765         NO
#
# [101766 rows x 50 columns]

# %%
#Dropping all coloumns with more than 50% NaN values
emptyy = pd.DataFrame(df_2, columns = ['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id', 'time_in_hospital', 'payer_code', 'medical_specialty', 'num_lab_procedures', 'num_procedures', 'num_medications', 'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1', 'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult', 'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone', 'tolazamide', 'examide', 'citoglipton', 'insulin', 'glyburide-metformin', 'glipizide-metformin','glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'])

percentage = 50
min_count =  int(((100-percentage)/100)*emptyy.shape[0] + 1)
df_3 = emptyy.dropna( axis=1, thresh=min_count)

df_3
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 0            2278392      8222157        Caucasian  Female   [0-10)
# 1             149190     55629189        Caucasian  Female  [10-20)
# 2              64410     86047875  AfricanAmerican  Female  [20-30)
# 3             500364     82442376        Caucasian    Male  [30-40)
# 4              16680     42519267        Caucasian    Male  [40-50)
# ...              ...          ...              ...     ...      ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)
# 101763     443854148     41088789        Caucasian    Male  [70-80)
# 101764     443857166     31693671        Caucasian  Female  [80-90)
# 101765     443867222    175429310        Caucasian    Male  [70-80)
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                       6                        25                    1
# 1                       1                         1                    7
# 2                       1                         1                    7
# 3                       1                         1                    7
# 4                       1                         1                    7
# ...                   ...                       ...                  ...
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital payer_code  ... citoglipton  insulin  \
# 0                      1        NaN  ...          No       No
# 1                      3        NaN  ...          No       Up
# 2                      2        NaN  ...          No       No
# 3                      2        NaN  ...          No       Up
# 4                      1        NaN  ...          No   Steady
# ...                  ...        ...  ...         ...      ...
# 101761                 3         MC  ...          No     Down
# 101762                 5         MC  ...          No   Steady
# 101763                 1         MC  ...          No     Down
# 101764                10         MC  ...          No       Up
# 101765                 6        NaN  ...          No       No
#
#         glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
# 0                        No                   No                        No
# 1                        No                   No                        No
# 2                        No                   No                        No
# 3                        No                   No                        No
# 4                        No                   No                        No
# ...                     ...                  ...                       ...
# 101761                   No                   No                        No
# 101762                   No                   No                        No
# 101763                   No                   No                        No
# 101764                   No                   No                        No
# 101765                   No                   No                        No
#
#         metformin-rosiglitazone  metformin-pioglitazone change diabetesMed  \
# 0                            No                      No     No          No
# 1                            No                      No     Ch         Yes
# 2                            No                      No     No         Yes
# 3                            No                      No     Ch         Yes
# 4                            No                      No     Ch         Yes
# ...                         ...                     ...    ...         ...
# 101761                       No                      No     Ch         Yes
# 101762                       No                      No     No         Yes
# 101763                       No                      No     Ch         Yes
# 101764                       No                      No     Ch         Yes
# 101765                       No                      No     No          No
#
#        readmitted
# 0              NO
# 1             >30
# 2              NO
# 3              NO
# 4              NO
# ...           ...
# 101761        >30
# 101762         NO
# 101763         NO
# 101764         NO
# 101765         NO
#
# [101766 rows x 49 columns]

# %%
#Drop columns with more than 95% repeated values

columns = []
percentage_to_drop = 0.95 #define the percentage criterion for drop
for cols in df_3.columns:
    counter = df_3[cols].value_counts().reset_index()
    counter['drop_percentage'] = counter[cols]/df_3.shape[0]
    counter['drop_criterion']  = counter['drop_percentage'] > percentage_to_drop
    if True in counter.drop_criterion.values:
        columns.append(cols)
df_4 = df_3.drop(columns= columns,axis=1)
df_4
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 0            2278392      8222157        Caucasian  Female   [0-10)
# 1             149190     55629189        Caucasian  Female  [10-20)
# 2              64410     86047875  AfricanAmerican  Female  [20-30)
# 3             500364     82442376        Caucasian    Male  [30-40)
# 4              16680     42519267        Caucasian    Male  [40-50)
# ...              ...          ...              ...     ...      ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)
# 101763     443854148     41088789        Caucasian    Male  [70-80)
# 101764     443857166     31693671        Caucasian  Female  [80-90)
# 101765     443867222    175429310        Caucasian    Male  [70-80)
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                       6                        25                    1
# 1                       1                         1                    7
# 2                       1                         1                    7
# 3                       1                         1                    7
# 4                       1                         1                    7
# ...                   ...                       ...                  ...
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital payer_code  ... metformin  glimepiride  glipizide  \
# 0                      1        NaN  ...        No           No         No
# 1                      3        NaN  ...        No           No         No
# 2                      2        NaN  ...        No           No     Steady
# 3                      2        NaN  ...        No           No         No
# 4                      1        NaN  ...        No           No     Steady
# ...                  ...        ...  ...       ...          ...        ...
# 101761                 3         MC  ...    Steady           No         No
# 101762                 5         MC  ...        No           No         No
# 101763                 1         MC  ...    Steady           No         No
# 101764                10         MC  ...        No           No     Steady
# 101765                 6        NaN  ...        No           No         No
#
#         glyburide  pioglitazone  rosiglitazone  insulin change diabetesMed  \
# 0              No            No             No       No     No          No
# 1              No            No             No       Up     Ch         Yes
# 2              No            No             No       No     No         Yes
# 3              No            No             No       Up     Ch         Yes
# 4              No            No             No   Steady     Ch         Yes
# ...           ...           ...            ...      ...    ...         ...
# 101761         No            No             No     Down     Ch         Yes
# 101762         No            No             No   Steady     No         Yes
# 101763         No            No             No     Down     Ch         Yes
# 101764         No        Steady             No       Up     Ch         Yes
# 101765         No            No             No       No     No          No
#
#        readmitted
# 0              NO
# 1             >30
# 2              NO
# 3              NO
# 4              NO
# ...           ...
# 101761        >30
# 101762         NO
# 101763         NO
# 101764         NO
# 101765         NO
#
# [101766 rows x 33 columns]

# %%
#Transforming age to be the middle value
df_5 = df_4
df_5['age'] = df_5.age.str.extract('(\d+)-(\d+)').astype('int').mean(axis=1).astype('int').round(0)

df_5
# Out:
#         encounter_id  patient_nbr             race  gender  age  \
# 0            2278392      8222157        Caucasian  Female    5
# 1             149190     55629189        Caucasian  Female   15
# 2              64410     86047875  AfricanAmerican  Female   25
# 3             500364     82442376        Caucasian    Male   35
# 4              16680     42519267        Caucasian    Male   45
# ...              ...          ...              ...     ...  ...
# 101761     443847548    100162476  AfricanAmerican    Male   75
# 101762     443847782     74694222  AfricanAmerican  Female   85
# 101763     443854148     41088789        Caucasian    Male   75
# 101764     443857166     31693671        Caucasian  Female   85
# 101765     443867222    175429310        Caucasian    Male   75
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                       6                        25                    1
# 1                       1                         1                    7
# 2                       1                         1                    7
# 3                       1                         1                    7
# 4                       1                         1                    7
# ...                   ...                       ...                  ...
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital payer_code  ... metformin  glimepiride  glipizide  \
# 0                      1        NaN  ...        No           No         No
# 1                      3        NaN  ...        No           No         No
# 2                      2        NaN  ...        No           No     Steady
# 3                      2        NaN  ...        No           No         No
# 4                      1        NaN  ...        No           No     Steady
# ...                  ...        ...  ...       ...          ...        ...
# 101761                 3         MC  ...    Steady           No         No
# 101762                 5         MC  ...        No           No         No
# 101763                 1         MC  ...    Steady           No         No
# 101764                10         MC  ...        No           No     Steady
# 101765                 6        NaN  ...        No           No         No
#
#         glyburide  pioglitazone  rosiglitazone  insulin change diabetesMed  \
# 0              No            No             No       No     No          No
# 1              No            No             No       Up     Ch         Yes
# 2              No            No             No       No     No         Yes
# 3              No            No             No       Up     Ch         Yes
# 4              No            No             No   Steady     Ch         Yes
# ...           ...           ...            ...      ...    ...         ...
# 101761         No            No             No     Down     Ch         Yes
# 101762         No            No             No   Steady     No         Yes
# 101763         No            No             No     Down     Ch         Yes
# 101764         No        Steady             No       Up     Ch         Yes
# 101765         No            No             No       No     No          No
#
#        readmitted
# 0              NO
# 1             >30
# 2              NO
# 3              NO
# 4              NO
# ...           ...
# 101761        >30
# 101762         NO
# 101763         NO
# 101764         NO
# 101765         NO
#
# [101766 rows x 33 columns]

# %%
#Replace missing values in diag_1, diag_2, and diag_3 to 0
df_5['diag_1'].fillna(0,inplace=True)
df_5['diag_2'].fillna(0,inplace=True)
df_5['diag_3'].fillna(0,inplace=True)

df_5
# Out:
#         encounter_id  patient_nbr             race  gender  age  \
# 0            2278392      8222157        Caucasian  Female    5
# 1             149190     55629189        Caucasian  Female   15
# 2              64410     86047875  AfricanAmerican  Female   25
# 3             500364     82442376        Caucasian    Male   35
# 4              16680     42519267        Caucasian    Male   45
# ...              ...          ...              ...     ...  ...
# 101761     443847548    100162476  AfricanAmerican    Male   75
# 101762     443847782     74694222  AfricanAmerican  Female   85
# 101763     443854148     41088789        Caucasian    Male   75
# 101764     443857166     31693671        Caucasian  Female   85
# 101765     443867222    175429310        Caucasian    Male   75
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                       6                        25                    1
# 1                       1                         1                    7
# 2                       1                         1                    7
# 3                       1                         1                    7
# 4                       1                         1                    7
# ...                   ...                       ...                  ...
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital payer_code  ... metformin  glimepiride  glipizide  \
# 0                      1        NaN  ...        No           No         No
# 1                      3        NaN  ...        No           No         No
# 2                      2        NaN  ...        No           No     Steady
# 3                      2        NaN  ...        No           No         No
# 4                      1        NaN  ...        No           No     Steady
# ...                  ...        ...  ...       ...          ...        ...
# 101761                 3         MC  ...    Steady           No         No
# 101762                 5         MC  ...        No           No         No
# 101763                 1         MC  ...    Steady           No         No
# 101764                10         MC  ...        No           No     Steady
# 101765                 6        NaN  ...        No           No         No
#
#         glyburide  pioglitazone  rosiglitazone  insulin change diabetesMed  \
# 0              No            No             No       No     No          No
# 1              No            No             No       Up     Ch         Yes
# 2              No            No             No       No     No         Yes
# 3              No            No             No       Up     Ch         Yes
# 4              No            No             No   Steady     Ch         Yes
# ...           ...           ...            ...      ...    ...         ...
# 101761         No            No             No     Down     Ch         Yes
# 101762         No            No             No   Steady     No         Yes
# 101763         No            No             No     Down     Ch         Yes
# 101764         No        Steady             No       Up     Ch         Yes
# 101765         No            No             No       No     No          No
#
#        readmitted
# 0              NO
# 1             >30
# 2              NO
# 3              NO
# 4              NO
# ...           ...
# 101761        >30
# 101762         NO
# 101763         NO
# 101764         NO
# 101765         NO
#
# [101766 rows x 33 columns]

# %%
#Drop all rows with missing values
df_6 = df_5.dropna()
df_6
# Out:
#         encounter_id  patient_nbr       race  gender  age  admission_type_id  \
# 20446       72091308     20123568  Caucasian  Female   75                  1
# 20737       72848634     20377854  Caucasian  Female   65                  2
# 20824       73062156     20408121  Caucasian  Female   95                  1
# 21083       73731852     20542797  Caucasian    Male   75                  1
# 23879       81355914      7239654  Caucasian  Female   75                  1
# ...              ...          ...        ...     ...  ...                ...
# 101735     443739044    106595208  Caucasian    Male   75                  2
# 101743     443793668     47293812  Caucasian    Male   85                  1
# 101747     443804570     33230016  Caucasian  Female   75                  1
# 101749     443816024    106392411  Caucasian  Female   75                  3
# 101764     443857166     31693671  Caucasian  Female   85                  2
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# 20446                         22                    7                 7
# 20737                          1                    1                 3
# 20824                          1                    7                 4
# 21083                          2                    7                10
# 23879                          3                    6                12
# ...                          ...                  ...               ...
# 101735                         6                    7                 6
# 101743                        13                    7                 3
# 101747                        22                    7                 8
# 101749                         6                    1                 3
# 101764                         3                    7                10
#
#        payer_code  ... metformin  glimepiride  glipizide  glyburide  \
# 20446          MC  ...        No           No         No         No
# 20737          MC  ...        No           No         No         No
# 20824          MC  ...        No       Steady         No         No
# 21083          MC  ...    Steady           No         No         No
# 23879          UN  ...        No           No         No         No
# ...           ...  ...       ...          ...        ...        ...
# 101735         MC  ...        No           No         No         No
# 101743         MC  ...        No           No         No         Up
# 101747         MC  ...        No           No         No         No
# 101749         MC  ...    Steady           No     Steady         No
# 101764         MC  ...        No           No     Steady         No
#
#         pioglitazone  rosiglitazone  insulin change diabetesMed readmitted
# 20446             Up             No   Steady     Ch         Yes         NO
# 20737             No             No   Steady     No         Yes         NO
# 20824             No             No       No     No         Yes         NO
# 21083             No             No   Steady     Ch         Yes         NO
# 23879             No             No   Steady     No         Yes         NO
# ...              ...            ...      ...    ...         ...        ...
# 101735            No             No       Up     Ch         Yes         NO
# 101743            No         Steady     Down     Ch         Yes         NO
# 101747            No             No   Steady     No         Yes        >30
# 101749            No             No   Steady     Ch         Yes         NO
# 101764        Steady             No       Up     Ch         Yes         NO
#
# [27140 rows x 33 columns]

# %%
#Shows columns that are ints and objects
df_6.dtypes
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                          int64
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# payer_code                  object
# medical_specialty           object
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# glimepiride                 object
# glipizide                   object
# glyburide                   object
# pioglitazone                object
# rosiglitazone               object
# insulin                     object
# change                      object
# diabetesMed                 object
# readmitted                  object
# dtype: object

# %%
#Dataframe of numerical features

df_7 = df_6.select_dtypes(include= [np.number])
df_7
# Out:
#         encounter_id  patient_nbr  age  admission_type_id  \
# 20446       72091308     20123568   75                  1
# 20737       72848634     20377854   65                  2
# 20824       73062156     20408121   95                  1
# 21083       73731852     20542797   75                  1
# 23879       81355914      7239654   75                  1
# ...              ...          ...  ...                ...
# 101735     443739044    106595208   75                  2
# 101743     443793668     47293812   85                  1
# 101747     443804570     33230016   75                  1
# 101749     443816024    106392411   75                  3
# 101764     443857166     31693671   85                  2
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# 20446                         22                    7                 7
# 20737                          1                    1                 3
# 20824                          1                    7                 4
# 21083                          2                    7                10
# 23879                          3                    6                12
# ...                          ...                  ...               ...
# 101735                         6                    7                 6
# 101743                        13                    7                 3
# 101747                        22                    7                 8
# 101749                         6                    1                 3
# 101764                         3                    7                10
#
#         num_lab_procedures  num_procedures  num_medications  \
# 20446                   58               2               15
# 20737                   59               3               11
# 20824                   56               1                9
# 21083                   68               1               18
# 23879                   77               5               19
# ...                    ...             ...              ...
# 101735                  46               5               14
# 101743                  45               0               26
# 101747                  51               6               19
# 101749                  27               1               29
# 101764                  45               2               21
#
#         number_outpatient  number_emergency  number_inpatient  \
# 20446                   0                 0                 0
# 20737                   0                 0                 0
# 20824                   0                 0                 0
# 21083                   0                 0                 0
# 23879                   0                 0                 0
# ...                   ...               ...               ...
# 101735                  0                 0                 1
# 101743                  1                 0                 1
# 101747                  0                 0                 0
# 101749                  0                 1                 0
# 101764                  0                 0                 1
#
#         number_diagnoses
# 20446                  9
# 20737                  6
# 20824                  6
# 21083                  6
# 23879                  5
# ...                  ...
# 101735                 9
# 101743                 9
# 101747                 9
# 101749                 9
# 101764                 9
#
# [27140 rows x 14 columns]

# %%
#List of columns with numerical features
numList = [col for col in df_7.columns]
numList
# Out:
# ['encounter_id',
#  'patient_nbr',
#  'age',
#  'admission_type_id',
#  'discharge_disposition_id',
#  'admission_source_id',
#  'time_in_hospital',
#  'num_lab_procedures',
#  'num_procedures',
#  'num_medications',
#  'number_outpatient',
#  'number_emergency',
#  'number_inpatient',
#  'number_diagnoses']

# %%
#Dataframe of categorical features
df_8 = df_6.select_dtypes(include= [np.object])
df_8
# Out:
#              race  gender payer_code           medical_specialty diag_1  \
# 20446   Caucasian  Female         MC  Orthopedics-Reconstructive    821
# 20737   Caucasian  Female         MC                  Nephrology    V56
# 20824   Caucasian  Female         MC            Emergency/Trauma    532
# 21083   Caucasian    Male         MC            InternalMedicine    682
# 23879   Caucasian  Female         UN            InternalMedicine    238
# ...           ...     ...        ...                         ...    ...
# 101735  Caucasian    Male         MC            Emergency/Trauma    575
# 101743  Caucasian    Male         MC            Emergency/Trauma    486
# 101747  Caucasian  Female         MC            InternalMedicine    410
# 101749  Caucasian  Female         MC                 Orthopedics    715
# 101764  Caucasian  Female         MC             Surgery-General    996
#
#         diag_2 diag_3 max_glu_serum A1Cresult metformin glimepiride glipizide  \
# 20446      276    285          None      None        No          No        No
# 20737      403    599          None      None        No          No        No
# 20824      428    535          None      None        No      Steady        No
# 21083      427    276          None      None    Steady          No        No
# 23879   250.02    733          None        >8        No          No        No
# ...        ...    ...           ...       ...       ...         ...       ...
# 101735     577    250          None      Norm        No          No        No
# 101743     276    428          None      None        No          No        No
# 101747     311    250          None        >7        No          No        No
# 101749     401    250          None      Norm    Steady          No    Steady
# 101764     285    998          None      None        No          No    Steady
#
#        glyburide pioglitazone rosiglitazone insulin change diabetesMed  \
# 20446         No           Up            No  Steady     Ch         Yes
# 20737         No           No            No  Steady     No         Yes
# 20824         No           No            No      No     No         Yes
# 21083         No           No            No  Steady     Ch         Yes
# 23879         No           No            No  Steady     No         Yes
# ...          ...          ...           ...     ...    ...         ...
# 101735        No           No            No      Up     Ch         Yes
# 101743        Up           No        Steady    Down     Ch         Yes
# 101747        No           No            No  Steady     No         Yes
# 101749        No           No            No  Steady     Ch         Yes
# 101764        No       Steady            No      Up     Ch         Yes
#
#        readmitted
# 20446          NO
# 20737          NO
# 20824          NO
# 21083          NO
# 23879          NO
# ...           ...
# 101735         NO
# 101743         NO
# 101747        >30
# 101749         NO
# 101764         NO
#
# [27140 rows x 19 columns]

# %%
#List of columns with categorical features
catList = [col for col in df_8.columns]
catList
# Out:
# ['race',
#  'gender',
#  'payer_code',
#  'medical_specialty',
#  'diag_1',
#  'diag_2',
#  'diag_3',
#  'max_glu_serum',
#  'A1Cresult',
#  'metformin',
#  'glimepiride',
#  'glipizide',
#  'glyburide',
#  'pioglitazone',
#  'rosiglitazone',
#  'insulin',
#  'change',
#  'diabetesMed',
#  'readmitted']

# %%
#Identify outliers in numerical columns and remove them
#Check on this
for col in df_6.select_dtypes(include= np.number):
#     factor = 3
#     upper_lim = df_6[col].mean () + (df_6[col].std () * factor) 
#     lower_lim = df_6[col].mean () - (df_6[col].std () * factor)
#     df_9 = df_6[(df_6[col] < upper_lim) & (df_6[col] > lower_lim)]   
    mean = np.mean(df_6[col])
    std = np.std(df_6[col])
    df_9 = df_6[(df_6[col] > mean-(3*std)) & (df_6[col] < mean+(3*std))]


df_9.shape

# df_9 = df_7[(np.abs(stats.zscore(df_7)) < 3).all(axis=1)]
# df_9.shape

#df_10 = df_6[(np.abs(stats.zscore(df_6)) < 3).all(axis=1)]
# Out:
# (27098, 33)

# %%
#Remove duplicates in the column patient_nbr
df_10 = df_9.drop_duplicates('patient_nbr')
df_10.shape
# Out:
# (19696, 33)

# %%
#Data exploration Hint 3
df_10["readmitted"].replace({"NO": "0", ">30": "1", "<30":"1"}, inplace=True)
df_10
# Out:
# /usr/lib/python3/dist-packages/pandas/core/generic.py:6786: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
#         encounter_id  patient_nbr       race  gender  age  admission_type_id  \
# 20446       72091308     20123568  Caucasian  Female   75                  1
# 20737       72848634     20377854  Caucasian  Female   65                  2
# 20824       73062156     20408121  Caucasian  Female   95                  1
# 21083       73731852     20542797  Caucasian    Male   75                  1
# 23879       81355914      7239654  Caucasian  Female   75                  1
# ...              ...          ...        ...     ...  ...                ...
# 101688     443119916     34751961  Caucasian    Male   25                  1
# 101710     443207210     30370995      Other  Female   35                  2
# 101716     443237558     93806559      Other    Male   75                  2
# 101720     443266892    180189752  Caucasian    Male   55                  2
# 101749     443816024    106392411  Caucasian  Female   75                  3
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# 20446                         22                    7                 7
# 20737                          1                    1                 3
# 20824                          1                    7                 4
# 21083                          2                    7                10
# 23879                          3                    6                12
# ...                          ...                  ...               ...
# 101688                         1                    7                 4
# 101710                         1                    7                 3
# 101716                         3                    7                 8
# 101720                         1                    7                 5
# 101749                         6                    1                 3
#
#        payer_code  ... metformin  glimepiride  glipizide  glyburide  \
# 20446          MC  ...        No           No         No         No
# 20737          MC  ...        No           No         No         No
# 20824          MC  ...        No       Steady         No         No
# 21083          MC  ...    Steady           No         No         No
# 23879          UN  ...        No           No         No         No
# ...           ...  ...       ...          ...        ...        ...
# 101688         SP  ...        No           No         No         No
# 101710         MD  ...    Steady           No         No         No
# 101716         SP  ...        No           No         No         No
# 101720         BC  ...        No           Up         No         No
# 101749         MC  ...    Steady           No     Steady         No
#
#         pioglitazone  rosiglitazone  insulin change diabetesMed readmitted
# 20446             Up             No   Steady     Ch         Yes          0
# 20737             No             No   Steady     No         Yes          0
# 20824             No             No       No     No         Yes          0
# 21083             No             No   Steady     Ch         Yes          0
# 23879             No             No   Steady     No         Yes          0
# ...              ...            ...      ...    ...         ...        ...
# 101688            No             No       Up     Ch         Yes          0
# 101710            No             No   Steady     Ch         Yes          0
# 101716            No             No     Down     Ch         Yes          0
# 101720        Steady             No     Down     Ch         Yes          1
# 101749            No             No   Steady     Ch         Yes          0
#
# [19696 rows x 33 columns]

# %%
#Age impact on readmissions
#Check this
df_11 = pd.DataFrame(df_10.groupby("age")["readmitted"].value_counts())
#df_11
#df_11 = df_10.groupby("age")["readmitted"].value_counts()
df_11.plot.bar(figsize=(12, 8))

# %%
#Impact of race on readmissions
df_12 = pd.DataFrame(df_10.groupby("race")["readmitted"].value_counts())
df_12.plot.bar(figsize=(12, 8))

# %%
#Gender impact on readmissions
df_13 = pd.DataFrame(df_10.groupby("gender")["readmitted"].value_counts())
df_13.plot.bar(figsize=(12, 8))

# %%
#Diagnose types impact on readmission rates
#This is wrong
#icdCodes

grouped = pd.DataFrame(df_10.groupby(['diag_1'])['readmitted'].value_counts())
grouped
# Out:
#                    readmitted
# diag_1 readmitted
# 0      0                    1
# 10     0                    1
# 11     0                    2
#        1                    1
# 112    0                    7
# ...                       ...
# V57    1                   28
# V58    1                   23
#        0                    8
# V71    0                    3
#        1                    1
#
# [916 rows x 1 columns]

# %%
# frames = pd.concat(icdCodes, df_10)
# frames

# %%
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix


icdCodes.shape


description = []

for index, row in df_10.iterrows():
  diag = df_10.diag_1[index]
  descRow = icdCodes[(icdCodes['ICD_Code'] == diag)]
  try:
    desc = descRow['Description'].values[0]
    description.append(desc)
  except:
    description.append("None")


df_10['Description'] = description

df_10
# Out:
# <ipython-input-25-9d12f270ba73>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_10['Description'] = description
#         encounter_id  patient_nbr       race  gender  age  admission_type_id  \
# 20446       72091308     20123568  Caucasian  Female   75                  1
# 20737       72848634     20377854  Caucasian  Female   65                  2
# 20824       73062156     20408121  Caucasian  Female   95                  1
# 21083       73731852     20542797  Caucasian    Male   75                  1
# 23879       81355914      7239654  Caucasian  Female   75                  1
# ...              ...          ...        ...     ...  ...                ...
# 101688     443119916     34751961  Caucasian    Male   25                  1
# 101710     443207210     30370995      Other  Female   35                  2
# 101716     443237558     93806559      Other    Male   75                  2
# 101720     443266892    180189752  Caucasian    Male   55                  2
# 101749     443816024    106392411  Caucasian  Female   75                  3
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# 20446                         22                    7                 7
# 20737                          1                    1                 3
# 20824                          1                    7                 4
# 21083                          2                    7                10
# 23879                          3                    6                12
# ...                          ...                  ...               ...
# 101688                         1                    7                 4
# 101710                         1                    7                 3
# 101716                         3                    7                 8
# 101720                         1                    7                 5
# 101749                         6                    1                 3
#
#        payer_code  ... glimepiride  glipizide  glyburide  pioglitazone  \
# 20446          MC  ...          No         No         No            Up
# 20737          MC  ...          No         No         No            No
# 20824          MC  ...      Steady         No         No            No
# 21083          MC  ...          No         No         No            No
# 23879          UN  ...          No         No         No            No
# ...           ...  ...         ...        ...        ...           ...
# 101688         SP  ...          No         No         No            No
# 101710         MD  ...          No         No         No            No
# 101716         SP  ...          No         No         No            No
# 101720         BC  ...          Up         No         No        Steady
# 101749         MC  ...          No     Steady         No            No
#
#         rosiglitazone  insulin  change diabetesMed readmitted  \
# 20446              No   Steady      Ch         Yes          0
# 20737              No   Steady      No         Yes          0
# 20824              No       No      No         Yes          0
# 21083              No   Steady      Ch         Yes          0
# 23879              No   Steady      No         Yes          0
# ...               ...      ...     ...         ...        ...
# 101688             No       Up      Ch         Yes          0
# 101710             No   Steady      Ch         Yes          0
# 101716             No     Down      Ch         Yes          0
# 101720             No     Down      Ch         Yes          1
# 101749             No   Steady      Ch         Yes          0
#
#                                               Description
# 20446    Fracture of other and unspecified parts of femur
# 20737           Aftercare involving intermittent dialysis
# 20824                                      Duodenal ulcer
# 21083                        Other cellulitis and abscess
# 23879   Neoplasm of uncertain behaviour of other and u...
# ...                                                   ...
# 101688  Diabetes with ketoacidosis, type I [juvenile t...
# 101710                                   General symptoms
# 101716                                     Cholelithiasis
# 101720                                Acute renal failure
# 101749               Osteo-arthrosis and allied disorders
#
# [19696 rows x 34 columns]
